# %% [markdown]
# # Ziling Zhang HW_2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %matplotlib inline

# %% [markdown]
# ## Q1

# %%
def get_data(token, exchange):
    res = requests.get(
        f'https://api.cryptowat.ch/markets/{exchange}/{token}usd/ohlc',
        params={
            'periods': '3600',
            'after': str(int(pd.Timestamp('2021-11-22').timestamp()))
        }
    )

    df = pd.DataFrame(
        res.json()['result']['3600'],
        columns=['ts', 'open', 'high', 'low', 'close', 'volume', 'volumeUSD']
    )
    df['ts'] = pd.to_datetime(df.ts, unit='s')
    df['token'] = token
    
    return df

# %%
tokens = ['ETH', 'SOL', 'AVAX', 'USDT', 'FLOW']
exchanges = ['coinbase-pro', 'coinbase-pro', 'coinbase-pro', 'coinbase-pro', 'kraken']

# %%
dfs = [get_data(token, exchange) for token, exchange in zip(tokens, exchanges)]

# %%
df = pd.concat(dfs).set_index('ts')
df.head()
# Out:
#                         open     high      low    close       volume  \
# ts
# 2021-11-22 00:00:00  4317.98  4342.24  4246.07  4262.99  7262.562789
# 2021-11-22 01:00:00  4263.04  4270.34  4212.45  4234.37  8437.946084
# 2021-11-22 02:00:00  4234.87  4246.72  4171.17  4217.89  9259.725370
# 2021-11-22 03:00:00  4217.88  4223.48  4163.58  4193.47  9259.899519
# 2021-11-22 04:00:00  4192.95  4213.59  4147.00  4168.35  7934.546906
#
#                         volumeUSD token
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH
# 2021-11-22 01:00:00  3.574586e+07   ETH
# 2021-11-22 02:00:00  3.895639e+07   ETH
# 2021-11-22 03:00:00  3.882032e+07   ETH
# 2021-11-22 04:00:00  3.315476e+07   ETH

# %%
len(df)
# Out:
# 2825

# %% [markdown]
# ## Q2

# %%
USD_volume = df.groupby('token')['volumeUSD'].sum().sort_values

# %%
USD_volume = df.groupby('token')['volumeUSD'].sum().sort_values(ascending = False)

# %%
USD_volume.to_frame()
# Out:
#           volumeUSD
# token
# ETH    2.176907e+10
# SOL    7.147179e+09
# AVAX   3.569897e+09
# USDT   2.031328e+09
# FLOW   8.926501e+07

# %% [markdown]
# ## Q3

# %%
ETH_SOL_close_ratio = df.groupby('ts', as_index=False).apply(lambda x: x[x['token'] == 'ETH'].close/x[x['token'] == 'SOL'].close)

# %%
ETH_SOL_close_ratio.to_frame().head()
# Out:
#                            close
#   ts
# 0 2021-11-22 00:00:00  18.471694
# 1 2021-11-22 01:00:00  18.736150
# 2 2021-11-22 02:00:00  18.577985
# 3 2021-11-22 03:00:00  18.794937
# 4 2021-11-22 04:00:00  18.891059

# %%
ETH_SOL_close_ratio.index = ETH_SOL_close_ratio.index.droplevel(0)

# %%
ETH_SOL_close_ratio = ETH_SOL_close_ratio.to_frame().head()
ETH_SOL_close_ratio.head()
# Out:
#                          close
# ts
# 2021-11-22 00:00:00  18.471694
# 2021-11-22 01:00:00  18.736150
# 2021-11-22 02:00:00  18.577985
# 2021-11-22 03:00:00  18.794937
# 2021-11-22 04:00:00  18.891059

# %%
ETH_SOL_close_ratio.rename(columns={"close":"ratio_ETH_SOL"},inplace=True)

# %%
df = df.join(ETH_SOL_close_ratio, on='ts')
df.head()
# Out:
#                         open     high      low    close       volume  \
# ts
# 2021-11-22 00:00:00  4317.98  4342.24  4246.07  4262.99  7262.562789
# 2021-11-22 01:00:00  4263.04  4270.34  4212.45  4234.37  8437.946084
# 2021-11-22 02:00:00  4234.87  4246.72  4171.17  4217.89  9259.725370
# 2021-11-22 03:00:00  4217.88  4223.48  4163.58  4193.47  9259.899519
# 2021-11-22 04:00:00  4192.95  4213.59  4147.00  4168.35  7934.546906
#
#                         volumeUSD token  ratio_ETH_SOL
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH      18.471694
# 2021-11-22 01:00:00  3.574586e+07   ETH      18.736150
# 2021-11-22 02:00:00  3.895639e+07   ETH      18.577985
# 2021-11-22 03:00:00  3.882032e+07   ETH      18.794937
# 2021-11-22 04:00:00  3.315476e+07   ETH      18.891059

# %% [markdown]
# ## Q4

# %%
df.rename(columns={'volume':'volumeBase', 'volumeUSD': 'volumeTerm'},inplace=True)
df.head()
# Out:
#                         open     high      low    close   volumeBase  \
# ts
# 2021-11-22 00:00:00  4317.98  4342.24  4246.07  4262.99  7262.562789
# 2021-11-22 01:00:00  4263.04  4270.34  4212.45  4234.37  8437.946084
# 2021-11-22 02:00:00  4234.87  4246.72  4171.17  4217.89  9259.725370
# 2021-11-22 03:00:00  4217.88  4223.48  4163.58  4193.47  9259.899519
# 2021-11-22 04:00:00  4192.95  4213.59  4147.00  4168.35  7934.546906
#
#                        volumeTerm token  ratio_ETH_SOL
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH      18.471694
# 2021-11-22 01:00:00  3.574586e+07   ETH      18.736150
# 2021-11-22 02:00:00  3.895639e+07   ETH      18.577985
# 2021-11-22 03:00:00  3.882032e+07   ETH      18.794937
# 2021-11-22 04:00:00  3.315476e+07   ETH      18.891059

# %% [markdown]
# ## Q5

# %%
fat_table = pd.pivot_table(df, values='close', index='ts', columns=['token'],)

# %%
fat_table.head()
# Out:
# token                  AVAX      ETH    FLOW      SOL    USDT
# ts
# 2021-11-22 00:00:00  128.67  4262.99  14.150  230.785  1.0012
# 2021-11-22 01:00:00  134.85  4234.37  13.621  226.000  1.0013
# 2021-11-22 02:00:00  132.54  4217.89  13.753  227.037  1.0012
# 2021-11-22 03:00:00  133.38  4193.47  13.652  223.117  1.0011
# 2021-11-22 04:00:00  136.29  4168.35  13.581  220.652  1.0009

# %% [markdown]
# ## Q6

# %%
Return = fat_table.apply(lambda x: np.log(x)-np.log(x.shift(1)))
Return.head()
# Out:
# token                    AVAX       ETH      FLOW       SOL    USDT
# ts
# 2021-11-22 00:00:00       NaN       NaN       NaN       NaN     NaN
# 2021-11-22 01:00:00  0.046912 -0.006736 -0.038102 -0.020952  0.0001
# 2021-11-22 02:00:00 -0.017279 -0.003900  0.009644  0.004578 -0.0001
# 2021-11-22 03:00:00  0.006318 -0.005806 -0.007371 -0.017417 -0.0001
# 2021-11-22 04:00:00  0.021583 -0.006008 -0.005214 -0.011109 -0.0002

# %% [markdown]
# ## Q7

# %%
corr_mat_return = Return.corr()
corr_mat_return
# Out:
# token      AVAX       ETH      FLOW       SOL      USDT
# token
# AVAX   1.000000  0.642650  0.390959  0.619992 -0.018064
# ETH    0.642650  1.000000  0.565507  0.742477 -0.119233
# FLOW   0.390959  0.565507  1.000000  0.449759 -0.192447
# SOL    0.619992  0.742477  0.449759  1.000000  0.099878
# USDT  -0.018064 -0.119233 -0.192447  0.099878  1.000000

# %% [markdown]
# ## Q8

# %%
corr_mat_return.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_3cc35_row0_col0, #T_3cc35_row1_col1, #T_3cc35_row2_col2, #T_3cc35_row3_col3, #T_3cc35_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3cc35_row0_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_3cc35_row0_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_3cc35_row0_col3 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_3cc35_row0_col4 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_3cc35_row1_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_3cc35_row1_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_3cc35_row1_col3 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_3cc35_row1_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_3cc35_row2_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_3cc35_row2_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_3cc35_row2_col3 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_3cc35_row2_col4, #T_3cc35_row4_col0, #T_3cc35_row4_col1, #T_3cc35_row4_col2, #T_3cc35_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3cc35_row3_col0 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_3cc35_row3_col1 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_3cc35_row3_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_3cc35_row3_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# </style>
# <table id="T_3cc35_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >token</th>
#       <th class="col_heading level0 col0" >AVAX</th>
#       <th class="col_heading level0 col1" >ETH</th>
#       <th class="col_heading level0 col2" >FLOW</th>
#       <th class="col_heading level0 col3" >SOL</th>
#       <th class="col_heading level0 col4" >USDT</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >token</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cc35_level0_row0" class="row_heading level0 row0" >AVAX</th>
#       <td id="T_3cc35_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_3cc35_row0_col1" class="data row0 col1" >0.642650</td>
#       <td id="T_3cc35_row0_col2" class="data row0 col2" >0.390959</td>
#       <td id="T_3cc35_row0_col3" class="data row0 col3" >0.619992</td>
#       <td id="T_3cc35_row0_col4" class="data row0 col4" >-0.018064</td>
#     </tr>
#     <tr>
#       <th id="T_3cc35_level0_row1" class="row_heading level0 row1" >ETH</th>
#       <td id="T_3cc35_row1_col0" class="data row1 col0" >0.642650</td>
#       <td id="T_3cc35_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_3cc35_row1_col2" class="data row1 col2" >0.565507</td>
#       <td id="T_3cc35_row1_col3" class="data row1 col3" >0.742477</td>
#       <td id="T_3cc35_row1_col4" class="data row1 col4" >-0.119233</td>
#     </tr>
#     <tr>
#       <th id="T_3cc35_level0_row2" class="row_heading level0 row2" >FLOW</th>
#       <td id="T_3cc35_row2_col0" class="data row2 col0" >0.390959</td>
#       <td id="T_3cc35_row2_col1" class="data row2 col1" >0.565507</td>
#       <td id="T_3cc35_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_3cc35_row2_col3" class="data row2 col3" >0.449759</td>
#       <td id="T_3cc35_row2_col4" class="data row2 col4" >-0.192447</td>
#     </tr>
#     <tr>
#       <th id="T_3cc35_level0_row3" class="row_heading level0 row3" >SOL</th>
#       <td id="T_3cc35_row3_col0" class="data row3 col0" >0.619992</td>
#       <td id="T_3cc35_row3_col1" class="data row3 col1" >0.742477</td>
#       <td id="T_3cc35_row3_col2" class="data row3 col2" >0.449759</td>
#       <td id="T_3cc35_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_3cc35_row3_col4" class="data row3 col4" >0.099878</td>
#     </tr>
#     <tr>
#       <th id="T_3cc35_level0_row4" class="row_heading level0 row4" >USDT</th>
#       <td id="T_3cc35_row4_col0" class="data row4 col0" >-0.018064</td>
#       <td id="T_3cc35_row4_col1" class="data row4 col1" >-0.119233</td>
#       <td id="T_3cc35_row4_col2" class="data row4 col2" >-0.192447</td>
#       <td id="T_3cc35_row4_col3" class="data row4 col3" >0.099878</td>
#       <td id="T_3cc35_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
