# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ## Get the time series for the following cryptocurrencies from cryptowat.ch starting from 2021-11-22, hourly data
#
#     ETH
#     SOL
#     AVAX
#     USDT
#     FLOW

# %%
def get_data(token):
    
    if token == 'FLOW':
        exchange = 'kraken'
    else:
        exchange = 'coinbase-pro'
    res = requests.get(
        f'https://api.cryptowat.ch/markets/{exchange}/{token}usd/ohlc',
        params={
            'periods': '3600',
            'after': str(int(pd.Timestamp('2021-11-22').timestamp()))
        }
    )

    df = pd.DataFrame(
        res.json()['result']['3600'],
        columns=['ts', 'open', 'high', 'low', 'close', 'volume', 'volumeUSD']
    )
    df['ts'] = pd.to_datetime(df.ts, unit='s')
    df['token'] = token
    
    return df

# %%
tokens = ['ETH', 'SOL','AVAX', 'USDT', 'FLOW']

# %%
df_base = pd.concat(get_data(token) for token in tokens)

# %%
df = df_base.set_index('ts')

# %%
df.head()
# Out:
#                         open     high      low    close       volume  \
# ts
# 2021-11-22 00:00:00  4317.98  4342.24  4246.07  4262.99  7262.562789
# 2021-11-22 01:00:00  4263.04  4270.34  4212.45  4234.37  8437.946084
# 2021-11-22 02:00:00  4234.87  4246.72  4171.17  4217.89  9259.725370
# 2021-11-22 03:00:00  4217.88  4223.48  4163.58  4193.47  9259.899519
# 2021-11-22 04:00:00  4192.95  4213.59  4147.00  4168.35  7934.546906
#
#                         volumeUSD token
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH
# 2021-11-22 01:00:00  3.574586e+07   ETH
# 2021-11-22 02:00:00  3.895639e+07   ETH
# 2021-11-22 03:00:00  3.882032e+07   ETH
# 2021-11-22 04:00:00  3.315476e+07   ETH

# %%
df['token'].value_counts()
# Out:
# ETH     533
# SOL     533
# AVAX    533
# USDT    533
# FLOW    533
# Name: token, dtype: int64

# %% [markdown]
# ## Get the total USD volume traded for each token in a dataframe, sorted from highest volume to lowest volume

# %%
df.groupby('token')['volumeUSD'].sum().to_frame()
# Out:
#           volumeUSD
# token
# AVAX   3.402515e+09
# ETH    2.086614e+10
# FLOW   8.528089e+07
# SOL    6.824271e+09
# USDT   1.956472e+09

# %% [markdown]
# ## Add a column that calculates the close price ratio between ETH and SOL for each house (i.e. close price of ETH / close price of SOL for each period)

# %%
df2 = df.loc[df['token'] == 'ETH']['close'].rename('close_ETH').to_frame().join(
    df.loc[df['token'] == 'SOL']['close'].rename('close_SOL').to_frame()
)
df2['ETH_SOL_CLOSE_RATIO'] = df2['close_ETH'] / df2['close_SOL']

df = df.join(df2['ETH_SOL_CLOSE_RATIO'].to_frame())
del df2
df
# Out:
#                           open       high        low      close        volume  \
# ts
# 2021-11-22 00:00:00  4317.9800  4342.2400  4246.0700  4262.9900  7.262563e+03
# 2021-11-22 00:00:00   230.4830   234.6880   228.8050   230.7850  9.353180e+04
# 2021-11-22 00:00:00   131.6900   133.7900   127.7000   128.6700  9.686748e+04
# 2021-11-22 00:00:00     1.0010     1.0017     1.0009     1.0012  9.987681e+06
# 2021-11-22 00:00:00    13.8870    14.1690    13.8870    14.1500  2.326138e+04
# ...                        ...        ...        ...        ...           ...
# 2021-12-14 04:00:00  3781.7600  3800.4600  3774.9500  3776.2100  2.258430e+03
# 2021-12-14 04:00:00   154.7400   154.8800   153.2900   153.9700  2.692133e+04
# 2021-12-14 04:00:00    78.9600    79.4900    78.5100    78.6600  2.137019e+04
# 2021-12-14 04:00:00     1.0005     1.0005     1.0004     1.0005  7.847077e+05
# 2021-12-14 04:00:00     8.5570     8.5790     8.5310     8.5310  1.438987e+02
#
#                         volumeUSD token  ETH_SOL_CLOSE_RATIO
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH            18.471694
# 2021-11-22 00:00:00  2.172284e+07   SOL            18.471694
# 2021-11-22 00:00:00  1.267080e+07  AVAX            18.471694
# 2021-11-22 00:00:00  9.999090e+06  USDT            18.471694
# 2021-11-22 00:00:00  3.274755e+05  FLOW            18.471694
# ...                           ...   ...                  ...
# 2021-12-14 04:00:00  8.557043e+06   ETH            24.525622
# 2021-12-14 04:00:00  4.152349e+06   SOL            24.525622
# 2021-12-14 04:00:00  1.691930e+06  AVAX            24.525622
# 2021-12-14 04:00:00  7.850822e+05  USDT            24.525622
# 2021-12-14 04:00:00  1.230341e+03  FLOW            24.525622
#
# [2665 rows x 8 columns]

# %% [markdown]
# ## Change the name of the volume and volumeUSD columns to volumeBase and volumeTerm

# %%
df = df.rename(
    columns={
        'volume':'volumeBase',
        'volumeUSD':'volumeTerm'
    }
)
df
# Out:
#                           open       high        low      close    volumeBase  \
# ts
# 2021-11-22 00:00:00  4317.9800  4342.2400  4246.0700  4262.9900  7.262563e+03
# 2021-11-22 00:00:00   230.4830   234.6880   228.8050   230.7850  9.353180e+04
# 2021-11-22 00:00:00   131.6900   133.7900   127.7000   128.6700  9.686748e+04
# 2021-11-22 00:00:00     1.0010     1.0017     1.0009     1.0012  9.987681e+06
# 2021-11-22 00:00:00    13.8870    14.1690    13.8870    14.1500  2.326138e+04
# ...                        ...        ...        ...        ...           ...
# 2021-12-14 04:00:00  3781.7600  3800.4600  3774.9500  3776.2100  2.258430e+03
# 2021-12-14 04:00:00   154.7400   154.8800   153.2900   153.9700  2.692133e+04
# 2021-12-14 04:00:00    78.9600    79.4900    78.5100    78.6600  2.137019e+04
# 2021-12-14 04:00:00     1.0005     1.0005     1.0004     1.0005  7.847077e+05
# 2021-12-14 04:00:00     8.5570     8.5790     8.5310     8.5310  1.438987e+02
#
#                        volumeTerm token  ETH_SOL_CLOSE_RATIO
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH            18.471694
# 2021-11-22 00:00:00  2.172284e+07   SOL            18.471694
# 2021-11-22 00:00:00  1.267080e+07  AVAX            18.471694
# 2021-11-22 00:00:00  9.999090e+06  USDT            18.471694
# 2021-11-22 00:00:00  3.274755e+05  FLOW            18.471694
# ...                           ...   ...                  ...
# 2021-12-14 04:00:00  8.557043e+06   ETH            24.525622
# 2021-12-14 04:00:00  4.152349e+06   SOL            24.525622
# 2021-12-14 04:00:00  1.691930e+06  AVAX            24.525622
# 2021-12-14 04:00:00  7.850822e+05  USDT            24.525622
# 2021-12-14 04:00:00  1.230341e+03  FLOW            24.525622
#
# [2665 rows x 8 columns]

# %%
df
# Out:
#                           open       high        low      close        volume  \
# ts
# 2021-11-22 00:00:00  4317.9800  4342.2400  4246.0700  4262.9900  7.262563e+03
# 2021-11-22 00:00:00   230.4830   234.6880   228.8050   230.7850  9.353180e+04
# 2021-11-22 00:00:00   131.6900   133.7900   127.7000   128.6700  9.686748e+04
# 2021-11-22 00:00:00     1.0010     1.0017     1.0009     1.0012  9.987681e+06
# 2021-11-22 00:00:00    13.8870    14.1690    13.8870    14.1500  2.326138e+04
# ...                        ...        ...        ...        ...           ...
# 2021-12-14 04:00:00  3781.7600  3800.4600  3774.9500  3776.2100  2.258430e+03
# 2021-12-14 04:00:00   154.7400   154.8800   153.2900   153.9700  2.692133e+04
# 2021-12-14 04:00:00    78.9600    79.4900    78.5100    78.6600  2.137019e+04
# 2021-12-14 04:00:00     1.0005     1.0005     1.0004     1.0005  7.847077e+05
# 2021-12-14 04:00:00     8.5570     8.5790     8.5310     8.5310  1.438987e+02
#
#                         volumeUSD token  ETH_SOL_CLOSE_RATIO
# ts
# 2021-11-22 00:00:00  3.123077e+07   ETH            18.471694
# 2021-11-22 00:00:00  2.172284e+07   SOL            18.471694
# 2021-11-22 00:00:00  1.267080e+07  AVAX            18.471694
# 2021-11-22 00:00:00  9.999090e+06  USDT            18.471694
# 2021-11-22 00:00:00  3.274755e+05  FLOW            18.471694
# ...                           ...   ...                  ...
# 2021-12-14 04:00:00  8.557043e+06   ETH            24.525622
# 2021-12-14 04:00:00  4.152349e+06   SOL            24.525622
# 2021-12-14 04:00:00  1.691930e+06  AVAX            24.525622
# 2021-12-14 04:00:00  7.850822e+05  USDT            24.525622
# 2021-12-14 04:00:00  1.230341e+03  FLOW            24.525622
#
# [2665 rows x 8 columns]

# %% [markdown]
# ## create a fat table indexed by the timestamp, and each column is the close price of each token (i.e. this should be a table of 200 rows and 5 columns)

# %%
fat_table = df.loc[df['token'] == 'ETH']['close'].rename('close_ETH').to_frame().join(
    df.loc[df['token'] == 'SOL']['close'].rename('close_SOL').to_frame()).join(
    df.loc[df['token'] == 'AVAX']['close'].rename('close_AVAX').to_frame()).join(
    df.loc[df['token'] == 'USDT']['close'].rename('close_USDT').to_frame()).join(
    df.loc[df['token'] == 'FLOW']['close'].rename('close_FLOW').to_frame())
fat_table.head()
# Out:
#                      close_ETH  close_SOL  close_AVAX  close_USDT  close_FLOW
# ts
# 2021-11-22 00:00:00    4262.99    230.785      128.67      1.0012      14.150
# 2021-11-22 01:00:00    4234.37    226.000      134.85      1.0013      13.621
# 2021-11-22 02:00:00    4217.89    227.037      132.54      1.0012      13.753
# 2021-11-22 03:00:00    4193.47    223.117      133.38      1.0011      13.652
# 2021-11-22 04:00:00    4168.35    220.652      136.29      1.0009      13.581

# %% [markdown]
# ## calculate the hour by hour log return of the close price of each token (return is calculated by np.log(price_t / price_{t-1}))

# %%
fat_table['ETH_LOG_RETURN'] = np.log(fat_table['close_ETH'] / fat_table['close_ETH'].shift(1))
fat_table['SOL_LOG_RETURN'] = np.log(fat_table['close_SOL'] / fat_table['close_SOL'].shift(1))
fat_table['AVAX_LOG_RETURN'] = np.log(fat_table['close_AVAX'] / fat_table['close_AVAX'].shift(1))
fat_table['USDT_LOG_RETURN'] = np.log(fat_table['close_USDT'] / fat_table['close_USDT'].shift(1))
fat_table['FLOW_LOG_RETURN'] = np.log(fat_table['close_FLOW'] / fat_table['close_FLOW'].shift(1))
fat_table.head()
# Out:
#                      close_ETH  close_SOL  close_AVAX  close_USDT  close_FLOW  \
# ts
# 2021-11-22 00:00:00    4262.99    230.785      128.67      1.0012      14.150
# 2021-11-22 01:00:00    4234.37    226.000      134.85      1.0013      13.621
# 2021-11-22 02:00:00    4217.89    227.037      132.54      1.0012      13.753
# 2021-11-22 03:00:00    4193.47    223.117      133.38      1.0011      13.652
# 2021-11-22 04:00:00    4168.35    220.652      136.29      1.0009      13.581
#
#                      ETH_LOG_RETURN  SOL_LOG_RETURN  AVAX_LOG_RETURN  \
# ts
# 2021-11-22 00:00:00             NaN             NaN              NaN
# 2021-11-22 01:00:00       -0.006736       -0.020952         0.046912
# 2021-11-22 02:00:00       -0.003900        0.004578        -0.017279
# 2021-11-22 03:00:00       -0.005806       -0.017417         0.006318
# 2021-11-22 04:00:00       -0.006008       -0.011109         0.021583
#
#                      USDT_LOG_RETURN  FLOW_LOG_RETURN
# ts
# 2021-11-22 00:00:00              NaN              NaN
# 2021-11-22 01:00:00           0.0001        -0.038102
# 2021-11-22 02:00:00          -0.0001         0.009644
# 2021-11-22 03:00:00          -0.0001        -0.007371
# 2021-11-22 04:00:00          -0.0002        -0.005214

# %%
corr_table = fat_table[['ETH_LOG_RETURN','SOL_LOG_RETURN','AVAX_LOG_RETURN','USDT_LOG_RETURN','FLOW_LOG_RETURN']].corr()
corr_table
# Out:
#                  ETH_LOG_RETURN  SOL_LOG_RETURN  AVAX_LOG_RETURN  \
# ETH_LOG_RETURN         1.000000        0.737801         0.644433
# SOL_LOG_RETURN         0.737801        1.000000         0.622500
# AVAX_LOG_RETURN        0.644433        0.622500         1.000000
# USDT_LOG_RETURN       -0.118869        0.106857        -0.017875
# FLOW_LOG_RETURN        0.562097        0.445335         0.389020
#
#                  USDT_LOG_RETURN  FLOW_LOG_RETURN
# ETH_LOG_RETURN         -0.118869         0.562097
# SOL_LOG_RETURN          0.106857         0.445335
# AVAX_LOG_RETURN        -0.017875         0.389020
# USDT_LOG_RETURN         1.000000        -0.196579
# FLOW_LOG_RETURN        -0.196579         1.000000

# %%
corr_table.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_91778_row0_col0, #T_91778_row1_col1, #T_91778_row2_col2, #T_91778_row3_col3, #T_91778_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_91778_row0_col1 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_91778_row0_col2 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_91778_row0_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_91778_row0_col4 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_91778_row1_col0 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_91778_row1_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_91778_row1_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_91778_row1_col4 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_91778_row2_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_91778_row2_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_91778_row2_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_91778_row2_col4 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_91778_row3_col0, #T_91778_row3_col1, #T_91778_row3_col2, #T_91778_row3_col4, #T_91778_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_91778_row4_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_91778_row4_col1 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_91778_row4_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# </style>
# <table id="T_91778_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ETH_LOG_RETURN</th>
#       <th class="col_heading level0 col1" >SOL_LOG_RETURN</th>
#       <th class="col_heading level0 col2" >AVAX_LOG_RETURN</th>
#       <th class="col_heading level0 col3" >USDT_LOG_RETURN</th>
#       <th class="col_heading level0 col4" >FLOW_LOG_RETURN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91778_level0_row0" class="row_heading level0 row0" >ETH_LOG_RETURN</th>
#       <td id="T_91778_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_91778_row0_col1" class="data row0 col1" >0.737801</td>
#       <td id="T_91778_row0_col2" class="data row0 col2" >0.644433</td>
#       <td id="T_91778_row0_col3" class="data row0 col3" >-0.118869</td>
#       <td id="T_91778_row0_col4" class="data row0 col4" >0.562097</td>
#     </tr>
#     <tr>
#       <th id="T_91778_level0_row1" class="row_heading level0 row1" >SOL_LOG_RETURN</th>
#       <td id="T_91778_row1_col0" class="data row1 col0" >0.737801</td>
#       <td id="T_91778_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_91778_row1_col2" class="data row1 col2" >0.622500</td>
#       <td id="T_91778_row1_col3" class="data row1 col3" >0.106857</td>
#       <td id="T_91778_row1_col4" class="data row1 col4" >0.445335</td>
#     </tr>
#     <tr>
#       <th id="T_91778_level0_row2" class="row_heading level0 row2" >AVAX_LOG_RETURN</th>
#       <td id="T_91778_row2_col0" class="data row2 col0" >0.644433</td>
#       <td id="T_91778_row2_col1" class="data row2 col1" >0.622500</td>
#       <td id="T_91778_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_91778_row2_col3" class="data row2 col3" >-0.017875</td>
#       <td id="T_91778_row2_col4" class="data row2 col4" >0.389020</td>
#     </tr>
#     <tr>
#       <th id="T_91778_level0_row3" class="row_heading level0 row3" >USDT_LOG_RETURN</th>
#       <td id="T_91778_row3_col0" class="data row3 col0" >-0.118869</td>
#       <td id="T_91778_row3_col1" class="data row3 col1" >0.106857</td>
#       <td id="T_91778_row3_col2" class="data row3 col2" >-0.017875</td>
#       <td id="T_91778_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_91778_row3_col4" class="data row3 col4" >-0.196579</td>
#     </tr>
#     <tr>
#       <th id="T_91778_level0_row4" class="row_heading level0 row4" >FLOW_LOG_RETURN</th>
#       <td id="T_91778_row4_col0" class="data row4 col0" >0.562097</td>
#       <td id="T_91778_row4_col1" class="data row4 col1" >0.445335</td>
#       <td id="T_91778_row4_col2" class="data row4 col2" >0.389020</td>
#       <td id="T_91778_row4_col3" class="data row4 col3" >-0.196579</td>
#       <td id="T_91778_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
