# %% [markdown]
# # Pandas DataFrames (`pd.DataFrame`)

# %% [markdown]
# The pandas dataframe is the workhorse of most data science and analytics projects.  The dataframe represents the data you're working with as a table.  However, the flexibility of the dataframe is that each row **and** column is represented as a pandas Series, which allows for many powerful ways to mess around with the data

# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# First let's get some data so we can see what we can do with a data frame.  Don't worry about exactly what this function is doing, we will go over it in a bit.

# %%
def get_data(token):
    res = requests.get(
        f'https://api.cryptowat.ch/markets/coinbase-pro/{token}usd/ohlc',
        params={
            'periods': '3600',
            'after': str(int(pd.Timestamp('2021-12-01').timestamp()))
        }
    )

    df = pd.DataFrame(
        res.json()['result']['3600'],
        columns=['ts', 'open', 'high', 'low', 'close', 'volume', 'volumeUSD']
    )
    df['ts'] = pd.to_datetime(df.ts, unit='s')
    df['token'] = token
    
    return df

# %%
tokens = ['BTC', 'ETH', 'SOL', 'AAVE', 'COMP']

# %% [markdown]
# Don't worry too much about what is going on in the function below - we'll briefly go over it as it showcases the power of python, but it's not necessary for the class

# %%
dfs = [
    (lambda x: x.assign(chain=np.where(x.token.isin(['ETH', 'AAVE', 'COMP']), np.full(x.shape[0], 'ETH'), x.token)))(get_data(token)) 
    for token in tokens
]

# %%
df_base = pd.concat(get_data(token) for token in tokens)
df_base['chain'] = np.where(df_base.token.isin(['ETH', 'AAVE', 'COMP']), np.full(df_base.shape[0], 'ETH'), df_base.token)

# %%
df = df_base.set_index('ts')

# %% [markdown]
# ## Understanding the data frame

# %% [markdown]
# After loading the data in our data frame, we can now inspect what's inside.  We'll need to do this as often the data we will store will be impossible to inspect row by row, and we will need to check that our data loading was correct
#
# Let's check some basic properties of the data set:

# %% [markdown]
# We can see how many rows and columns this data frame has, and total number of data points

# %%
df.shape
# Out:
# (1460, 8)

# %%
df.size
# Out:
# 11680

# %% [markdown]
# We can see what the first 5 rows looks like:

# %%
df.head()
# Out:
#                          open      high       low     close      volume  \
# ts
# 2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97  388.482022
# 2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41  599.791578
# 2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83  591.687200
# 2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59  702.560364
# 2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01  859.591535
#
#                         volumeUSD token chain
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC   BTC
# 2021-12-01 01:00:00  3.437153e+07   BTC   BTC
# 2021-12-01 02:00:00  3.387067e+07   BTC   BTC
# 2021-12-01 03:00:00  4.007816e+07   BTC   BTC
# 2021-12-01 04:00:00  4.920503e+07   BTC   BTC

# %% [markdown]
# ...and the last 5 rows

# %%
df.tail()
# Out:
#                        open    high     low   close    volume     volumeUSD  \
# ts
# 2021-12-12 23:00:00  199.71  200.00  197.97  199.27   618.775  123024.49025
# 2021-12-13 00:00:00  199.27  200.05  198.30  198.62   296.920   59113.82992
# 2021-12-13 01:00:00  198.52  200.81  195.49  196.24  3363.459  663783.90199
# 2021-12-13 02:00:00  196.31  196.32  191.80  191.86  1901.019  369748.01226
# 2021-12-13 03:00:00  191.69  193.47  190.95  192.11   454.858   87473.43382
#
#                     token chain
# ts
# 2021-12-12 23:00:00  COMP   ETH
# 2021-12-13 00:00:00  COMP   ETH
# 2021-12-13 01:00:00  COMP   ETH
# 2021-12-13 02:00:00  COMP   ETH
# 2021-12-13 03:00:00  COMP   ETH

# %% [markdown]
# We can also see a general overview of the schema (column name, data and data type) of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1460 entries, 2021-12-01 00:00:00 to 2021-12-13 03:00:00
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   open       1460 non-null   float64
#  1   high       1460 non-null   float64
#  2   low        1460 non-null   float64
#  3   close      1460 non-null   float64
#  4   volume     1460 non-null   float64
#  5   volumeUSD  1460 non-null   float64
#  6   token      1460 non-null   object
#  7   chain      1460 non-null   object
# dtypes: float64(6), object(2)
# memory usage: 102.7+ KB

# %% [markdown]
# as well as descriptive statistics about every column

# %%
df.describe()
# Out:
#                open          high           low         close         volume  \
# count   1460.000000   1460.000000   1460.000000   1460.000000    1460.000000
# mean   11209.356016  11276.938413  11131.135530  11202.778737   16987.659321
# std    20101.662023  20218.374716  19966.832587  20089.482510   34912.560290
# min      165.280000    168.820000    161.510000    165.320000      67.178000
# 25%      193.647500    195.716500    191.797500    193.491750     784.116811
# 50%      238.113000    239.794500    235.296000    237.044500    2206.631000
# 75%     4413.157500   4432.662500   4377.775000   4411.615000   12528.347007
# max    58664.400000  59118.840000  58445.530000  58664.400000  534212.095000
#
#           volumeUSD
# count  1.460000e+03
# mean   1.916371e+07
# std    2.837019e+07
# min    1.821233e+04
# 25%    3.403129e+05
# 50%    1.088089e+07
# 75%    2.850002e+07
# max    3.988035e+08

# %% [markdown]
# ## DataFrame Indexing

# %% [markdown]
# Indexing in data frames works very similar to Series, however there are now two "axes" that we can operate on - rows and columns.  For example, using `[*]` for indexing (like in series) by default will operate on columns:

# %%
df['open']
# Out:
# ts
# 2021-12-01 00:00:00    57321.41
# 2021-12-01 01:00:00    56998.35
# 2021-12-01 02:00:00    57618.55
# 2021-12-01 03:00:00    57029.79
# 2021-12-01 04:00:00    57306.55
#                          ...
# 2021-12-12 23:00:00      199.71
# 2021-12-13 00:00:00      199.27
# 2021-12-13 01:00:00      198.52
# 2021-12-13 02:00:00      196.31
# 2021-12-13 03:00:00      191.69
# Name: open, Length: 1460, dtype: float64

# %% [markdown]
# however using `.loc[*]` will allow you to access rows:

# %%
df.loc['2021-12-01 01:00:00']
# Out:
#                           open       high        low      close        volume  \
# ts
# 2021-12-01 01:00:00  56998.350  57726.450  56705.060  57616.410    599.791578
# 2021-12-01 01:00:00   4636.430   4736.900   4605.490   4729.100  13819.061610
# 2021-12-01 01:00:00    208.716    211.773    207.821    211.507  92606.555000
# 2021-12-01 01:00:00    257.149    266.249    255.270    264.816   5752.541000
# 2021-12-01 01:00:00    278.650    283.800    276.360    283.440    817.668000
#
#                         volumeUSD token chain
# ts
# 2021-12-01 01:00:00  3.437153e+07   BTC   BTC
# 2021-12-01 01:00:00  6.487693e+07   ETH   ETH
# 2021-12-01 01:00:00  1.946153e+07   SOL   SOL
# 2021-12-01 01:00:00  1.516148e+06  AAVE   ETH
# 2021-12-01 01:00:00  2.292746e+05  COMP   ETH

# %% [markdown]
# and `.iloc[*]` will get you positional rows

# %%
df.iloc[0]
# Out:
# open               57321.41
# high               57451.05
# low                56814.34
# close              56987.97
# volume           388.482022
# volumeUSD    22184300.66241
# token                   BTC
# chain                   BTC
# Name: 2021-12-01 00:00:00, dtype: object

# %% [markdown]
# we can also get to the last row easily

# %%
df.iloc[-1]
# Out:
# open              191.69
# high              193.47
# low               190.95
# close             192.11
# volume           454.858
# volumeUSD    87473.43382
# token               COMP
# chain                ETH
# Name: 2021-12-13 03:00:00, dtype: object

# %% [markdown]
# or return it as a data frame instead of a Series

# %%
df.iloc[[-1]]
# Out:
#                        open    high     low   close   volume    volumeUSD  \
# ts
# 2021-12-13 03:00:00  191.69  193.47  190.95  192.11  454.858  87473.43382
#
#                     token chain
# ts
# 2021-12-13 03:00:00  COMP   ETH

# %% [markdown]
# **note**: `df.loc[0]` will not work, as this is accessing via index

# %% [markdown]
# ---
# **note**: Also, the index operators will return a `pd.Series` if there's 1 row returned, or a new `pd.DataFrame` if multiple rows are returned, e.g.:

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
type(df.loc['2021-12-01 01:00:00']) # 5 rows returned
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# we can convert a Series to a DataFrame anytime by using the `.to_frame()` method on the Series object.  This will turn the Series to a DataFrame, using the `Series.name` as the column name

# %%
df.iloc[0].to_frame()
# Out:
#                2021-12-01
# open             57321.41
# high             57451.05
# low              56814.34
# close            56987.97
# volume         388.482022
# volumeUSD  22184300.66241
# token                 BTC
# chain                 BTC

# %% [markdown]
# ---

# %% [markdown]
# In addition, we can select on multiple columns and rows in various ways:

# %%
df[['open', 'close']]
# Out:
#                          open     close
# ts
# 2021-12-01 00:00:00  57321.41  56987.97
# 2021-12-01 01:00:00  56998.35  57616.41
# 2021-12-01 02:00:00  57618.55  57030.83
# 2021-12-01 03:00:00  57029.79  57307.59
# 2021-12-01 04:00:00  57306.55  57404.01
# ...                       ...       ...
# 2021-12-12 23:00:00    199.71    199.27
# 2021-12-13 00:00:00    199.27    198.62
# 2021-12-13 01:00:00    198.52    196.24
# 2021-12-13 02:00:00    196.31    191.86
# 2021-12-13 03:00:00    191.69    192.11
#
# [1460 rows x 2 columns]

# %%
df[0:2]
# Out:
#                          open      high       low     close      volume  \
# ts
# 2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97  388.482022
# 2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41  599.791578
#
#                         volumeUSD token chain
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC   BTC
# 2021-12-01 01:00:00  3.437153e+07   BTC   BTC

# %%
df.loc['2021-12-01 00:00:00':'2021-12-01 02:00:00']
# Out:
#                           open       high        low      close        volume  \
# ts
# 2021-12-01 00:00:00  57321.410  57451.050  56814.340  56987.970    388.482022
# 2021-12-01 01:00:00  56998.350  57726.450  56705.060  57616.410    599.791578
# 2021-12-01 02:00:00  57618.550  57620.000  56972.970  57030.830    591.687200
# 2021-12-01 00:00:00   4656.620   4672.430   4624.160   4634.950   6013.006735
# 2021-12-01 01:00:00   4636.430   4736.900   4605.490   4729.100  13819.061610
# 2021-12-01 02:00:00   4729.100   4729.100   4684.490   4695.780   7491.465440
# 2021-12-01 00:00:00    210.312    210.590    208.432    208.676  70031.618000
# 2021-12-01 01:00:00    208.716    211.773    207.821    211.507  92606.555000
# 2021-12-01 02:00:00    211.506    212.235    210.003    210.868  49728.032000
# 2021-12-01 00:00:00    257.102    260.775    255.345    257.078   2730.299000
# 2021-12-01 01:00:00    257.149    266.249    255.270    264.816   5752.541000
# 2021-12-01 02:00:00    264.755    266.187    262.597    263.125   1559.330000
# 2021-12-01 00:00:00    280.590    281.400    278.300    278.700    207.849000
# 2021-12-01 01:00:00    278.650    283.800    276.360    283.440    817.668000
# 2021-12-01 02:00:00    283.200    283.200    280.610    281.290    254.330000
#
#                         volumeUSD token chain
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC   BTC
# 2021-12-01 01:00:00  3.437153e+07   BTC   BTC
# 2021-12-01 02:00:00  3.387067e+07   BTC   BTC
# 2021-12-01 00:00:00  2.793321e+07   ETH   ETH
# 2021-12-01 01:00:00  6.487693e+07   ETH   ETH
# 2021-12-01 02:00:00  3.524161e+07   ETH   ETH
# 2021-12-01 00:00:00  1.465851e+07   SOL   SOL
# 2021-12-01 01:00:00  1.946153e+07   SOL   SOL
# 2021-12-01 02:00:00  1.049756e+07   SOL   SOL
# 2021-12-01 00:00:00  7.039183e+05  AAVE   ETH
# 2021-12-01 01:00:00  1.516148e+06  AAVE   ETH
# 2021-12-01 02:00:00  4.124449e+05  AAVE   ETH
# 2021-12-01 00:00:00  5.822157e+04  COMP   ETH
# 2021-12-01 01:00:00  2.292746e+05  COMP   ETH
# 2021-12-01 02:00:00  7.160933e+04  COMP   ETH

# %%
df.iloc[0:4]
# Out:
#                          open      high       low     close      volume  \
# ts
# 2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97  388.482022
# 2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41  599.791578
# 2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83  591.687200
# 2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59  702.560364
#
#                         volumeUSD token chain
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC   BTC
# 2021-12-01 01:00:00  3.437153e+07   BTC   BTC
# 2021-12-01 02:00:00  3.387067e+07   BTC   BTC
# 2021-12-01 03:00:00  4.007816e+07   BTC   BTC

# %%
df.iloc[[0, 4, 10, 50]]
# Out:
#                          open      high       low     close      volume  \
# ts
# 2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97  388.482022
# 2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01  859.591535
# 2021-12-01 10:00:00  56945.94  57220.39  56756.48  57131.16  586.052971
# 2021-12-03 02:00:00  56569.30  56762.82  56425.99  56545.98  238.584708
#
#                         volumeUSD token chain
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC   BTC
# 2021-12-01 04:00:00  4.920503e+07   BTC   BTC
# 2021-12-01 10:00:00  3.340768e+07   BTC   BTC
# 2021-12-03 02:00:00  1.349612e+07   BTC   BTC

# %% [markdown]
# And finally, we can index on both rows and columns at the same time with `.loc`:

# %%
df.loc['2021-12-01 00:00:00':'2021-12-01 02:00:00', ['close', 'volume', 'token']]
# Out:
#                          close        volume token
# ts
# 2021-12-01 00:00:00  56987.970    388.482022   BTC
# 2021-12-01 01:00:00  57616.410    599.791578   BTC
# 2021-12-01 02:00:00  57030.830    591.687200   BTC
# 2021-12-01 00:00:00   4634.950   6013.006735   ETH
# 2021-12-01 01:00:00   4729.100  13819.061610   ETH
# 2021-12-01 02:00:00   4695.780   7491.465440   ETH
# 2021-12-01 00:00:00    208.676  70031.618000   SOL
# 2021-12-01 01:00:00    211.507  92606.555000   SOL
# 2021-12-01 02:00:00    210.868  49728.032000   SOL
# 2021-12-01 00:00:00    257.078   2730.299000  AAVE
# 2021-12-01 01:00:00    264.816   5752.541000  AAVE
# 2021-12-01 02:00:00    263.125   1559.330000  AAVE
# 2021-12-01 00:00:00    278.700    207.849000  COMP
# 2021-12-01 01:00:00    283.440    817.668000  COMP
# 2021-12-01 02:00:00    281.290    254.330000  COMP

# %% [markdown]
# **note**: Given that by default dataframe indices are sequential integers by default, it's good practice to use `.loc` and `.iloc` to index into the data frame to be very clear, for example, let's shuffle our data frame then select:

# %%
df_shuffled = df_base.sample(frac=1)

# %%
df_shuffled.loc[[0, 2, 3]]
# Out:
#                    ts       open       high        low      close  \
# 0 2021-12-01 00:00:00  57321.410  57451.050  56814.340  56987.970
# 0 2021-12-01 00:00:00    257.102    260.775    255.345    257.078
# 0 2021-12-01 00:00:00    210.312    210.590    208.432    208.676
# 0 2021-12-01 00:00:00    280.590    281.400    278.300    278.700
# 0 2021-12-01 00:00:00   4656.620   4672.430   4624.160   4634.950
# 2 2021-12-01 02:00:00    264.755    266.187    262.597    263.125
# 2 2021-12-01 02:00:00    211.506    212.235    210.003    210.868
# 2 2021-12-01 02:00:00  57618.550  57620.000  56972.970  57030.830
# 2 2021-12-01 02:00:00   4729.100   4729.100   4684.490   4695.780
# 2 2021-12-01 02:00:00    283.200    283.200    280.610    281.290
# 3 2021-12-01 03:00:00  57029.790  57396.870  56841.010  57307.590
# 3 2021-12-01 03:00:00    210.889    215.063    210.805    214.150
# 3 2021-12-01 03:00:00    281.250    283.220    279.900    283.090
# 3 2021-12-01 03:00:00   4695.780   4754.970   4672.300   4754.090
# 3 2021-12-01 03:00:00    263.184    266.409    261.700    266.257
#
#          volume     volumeUSD token chain
# 0    388.482022  2.218430e+07   BTC   BTC
# 0   2730.299000  7.039183e+05  AAVE   ETH
# 0  70031.618000  1.465851e+07   SOL   SOL
# 0    207.849000  5.822157e+04  COMP   ETH
# 0   6013.006735  2.793321e+07   ETH   ETH
# 2   1559.330000  4.124449e+05  AAVE   ETH
# 2  49728.032000  1.049756e+07   SOL   SOL
# 2    591.687200  3.387067e+07   BTC   BTC
# 2   7491.465440  3.524161e+07   ETH   ETH
# 2    254.330000  7.160933e+04  COMP   ETH
# 3    702.560364  4.007816e+07   BTC   BTC
# 3  70399.433000  1.498090e+07   SOL   SOL
# 3    393.771000  1.108907e+05  COMP   ETH
# 3  10530.834423  4.963273e+07   ETH   ETH
# 3   1647.398000  4.336408e+05  AAVE   ETH

# %%
df_shuffled.iloc[[0, 2, 3]]
# Out:
#                      ts      open      high      low     close        volume  \
# 57  2021-12-03 09:00:00   232.691   232.889   230.01   232.195  29521.347000
# 243 2021-12-11 03:00:00  3970.740  3997.990  3956.05  3992.210   4685.686108
# 266 2021-12-12 02:00:00   196.790   197.390   195.08   195.760    767.701000
#
#         volumeUSD token chain
# 57   6.821438e+06   SOL   SOL
# 243  1.864206e+07   ETH   ETH
# 266  1.506255e+05  COMP   ETH

# %% [markdown]
# lastly, we can set the DataFrame index from a column, or remove an index into a column

# %%
df_shuffled.set_index('ts')
# Out:
#                           open       high        low      close        volume  \
# ts
# 2021-12-03 09:00:00    232.691    232.889    230.010    232.195  29521.347000
# 2021-12-03 19:00:00    233.318    233.673    230.005    232.190   1491.289000
# 2021-12-11 03:00:00   3970.740   3997.990   3956.050   3992.210   4685.686108
# 2021-12-12 02:00:00    196.790    197.390    195.080    195.760    767.701000
# 2021-12-11 23:00:00   4028.670   4069.530   4011.160   4025.340   7077.641660
# ...                        ...        ...        ...        ...           ...
# 2021-12-07 16:00:00    194.570    197.407    194.366    196.343   2986.129000
# 2021-12-08 17:00:00   4407.730   4426.350   4370.840   4411.090  11455.200928
# 2021-12-11 17:00:00  48788.860  49306.830  48718.730  49011.400    610.683584
# 2021-12-07 14:00:00  50973.170  51145.760  50873.240  50974.970    490.110868
# 2021-12-12 19:00:00    181.460    182.380    181.460    181.960   2157.429000
#
#                         volumeUSD token chain
# ts
# 2021-12-03 09:00:00  6.821438e+06   SOL   SOL
# 2021-12-03 19:00:00  3.465333e+05  AAVE   ETH
# 2021-12-11 03:00:00  1.864206e+07   ETH   ETH
# 2021-12-12 02:00:00  1.506255e+05  COMP   ETH
# 2021-12-11 23:00:00  2.855341e+07   ETH   ETH
# ...                           ...   ...   ...
# 2021-12-07 16:00:00  5.842146e+05  AAVE   ETH
# 2021-12-08 17:00:00  5.041474e+07   ETH   ETH
# 2021-12-11 17:00:00  2.995077e+07   BTC   BTC
# 2021-12-07 14:00:00  2.499938e+07   BTC   BTC
# 2021-12-12 19:00:00  3.927535e+05  AAVE   ETH
#
# [1460 rows x 8 columns]

# %%
df_shuffled.set_index('ts').reset_index()
# Out:
#                       ts       open       high        low      close  \
# 0    2021-12-03 09:00:00    232.691    232.889    230.010    232.195
# 1    2021-12-03 19:00:00    233.318    233.673    230.005    232.190
# 2    2021-12-11 03:00:00   3970.740   3997.990   3956.050   3992.210
# 3    2021-12-12 02:00:00    196.790    197.390    195.080    195.760
# 4    2021-12-11 23:00:00   4028.670   4069.530   4011.160   4025.340
# ...                  ...        ...        ...        ...        ...
# 1455 2021-12-07 16:00:00    194.570    197.407    194.366    196.343
# 1456 2021-12-08 17:00:00   4407.730   4426.350   4370.840   4411.090
# 1457 2021-12-11 17:00:00  48788.860  49306.830  48718.730  49011.400
# 1458 2021-12-07 14:00:00  50973.170  51145.760  50873.240  50974.970
# 1459 2021-12-12 19:00:00    181.460    182.380    181.460    181.960
#
#             volume     volumeUSD token chain
# 0     29521.347000  6.821438e+06   SOL   SOL
# 1      1491.289000  3.465333e+05  AAVE   ETH
# 2      4685.686108  1.864206e+07   ETH   ETH
# 3       767.701000  1.506255e+05  COMP   ETH
# 4      7077.641660  2.855341e+07   ETH   ETH
# ...            ...           ...   ...   ...
# 1455   2986.129000  5.842146e+05  AAVE   ETH
# 1456  11455.200928  5.041474e+07   ETH   ETH
# 1457    610.683584  2.995077e+07   BTC   BTC
# 1458    490.110868  2.499938e+07   BTC   BTC
# 1459   2157.429000  3.927535e+05  AAVE   ETH
#
# [1460 rows x 9 columns]

# %% [markdown]
# ## DataFrame Filtering

# %% [markdown]
# Filtering a data frame is very similar to filtering a series.  We can filter on any set of columns, the filtering is done via indices.  For example, if we wanted to just get the data points for tokens on the ethereum chain:

# %%
df['chain'] == 'ETH'
# Out:
# ts
# 2021-12-01 00:00:00    False
# 2021-12-01 01:00:00    False
# 2021-12-01 02:00:00    False
# 2021-12-01 03:00:00    False
# 2021-12-01 04:00:00    False
#                        ...
# 2021-12-12 23:00:00     True
# 2021-12-13 00:00:00     True
# 2021-12-13 01:00:00     True
# 2021-12-13 02:00:00     True
# 2021-12-13 03:00:00     True
# Name: chain, Length: 1460, dtype: bool

# %%
df.loc[df['chain'] == 'ETH']
# Out:
#                         open     high      low    close        volume  \
# ts
# 2021-12-01 00:00:00  4656.62  4672.43  4624.16  4634.95   6013.006735
# 2021-12-01 01:00:00  4636.43  4736.90  4605.49  4729.10  13819.061610
# 2021-12-01 02:00:00  4729.10  4729.10  4684.49  4695.78   7491.465440
# 2021-12-01 03:00:00  4695.78  4754.97  4672.30  4754.09  10530.834423
# 2021-12-01 04:00:00  4754.09  4774.74  4722.02  4764.59  12471.624735
# ...                      ...      ...      ...      ...           ...
# 2021-12-12 23:00:00   199.71   200.00   197.97   199.27    618.775000
# 2021-12-13 00:00:00   199.27   200.05   198.30   198.62    296.920000
# 2021-12-13 01:00:00   198.52   200.81   195.49   196.24   3363.459000
# 2021-12-13 02:00:00   196.31   196.32   191.80   191.86   1901.019000
# 2021-12-13 03:00:00   191.69   193.47   190.95   192.11    454.858000
#
#                         volumeUSD token chain
# ts
# 2021-12-01 00:00:00  2.793321e+07   ETH   ETH
# 2021-12-01 01:00:00  6.487693e+07   ETH   ETH
# 2021-12-01 02:00:00  3.524161e+07   ETH   ETH
# 2021-12-01 03:00:00  4.963273e+07   ETH   ETH
# 2021-12-01 04:00:00  5.924627e+07   ETH   ETH
# ...                           ...   ...   ...
# 2021-12-12 23:00:00  1.230245e+05  COMP   ETH
# 2021-12-13 00:00:00  5.911383e+04  COMP   ETH
# 2021-12-13 01:00:00  6.637839e+05  COMP   ETH
# 2021-12-13 02:00:00  3.697480e+05  COMP   ETH
# 2021-12-13 03:00:00  8.747343e+04  COMP   ETH
#
# [876 rows x 8 columns]

# %%
df.loc[df['chain'] == 'ETH', 'close']
# Out:
# ts
# 2021-12-01 00:00:00    4634.95
# 2021-12-01 01:00:00    4729.10
# 2021-12-01 02:00:00    4695.78
# 2021-12-01 03:00:00    4754.09
# 2021-12-01 04:00:00    4764.59
#                         ...
# 2021-12-12 23:00:00     199.27
# 2021-12-13 00:00:00     198.62
# 2021-12-13 01:00:00     196.24
# 2021-12-13 02:00:00     191.86
# 2021-12-13 03:00:00     192.11
# Name: close, Length: 876, dtype: float64

# %% [markdown]
# ## Deleting from Dataframes

# %% [markdown]
# We can select for all the things we'd like, but we can also drop both rows and columns.  This also works by index, i.e.:

# %%
df.drop(pd.to_datetime('2021-12-01 00:00:00'))
# Out:
#                          open      high       low     close       volume  \
# ts
# 2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41   599.791578
# 2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83   591.687200
# 2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59   702.560364
# 2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01   859.591535
# 2021-12-01 05:00:00  57404.01  57460.42  57016.00  57084.36   566.037996
# ...                       ...       ...       ...       ...          ...
# 2021-12-12 23:00:00    199.71    200.00    197.97    199.27   618.775000
# 2021-12-13 00:00:00    199.27    200.05    198.30    198.62   296.920000
# 2021-12-13 01:00:00    198.52    200.81    195.49    196.24  3363.459000
# 2021-12-13 02:00:00    196.31    196.32    191.80    191.86  1901.019000
# 2021-12-13 03:00:00    191.69    193.47    190.95    192.11   454.858000
#
#                         volumeUSD token chain
# ts
# 2021-12-01 01:00:00  3.437153e+07   BTC   BTC
# 2021-12-01 02:00:00  3.387067e+07   BTC   BTC
# 2021-12-01 03:00:00  4.007816e+07   BTC   BTC
# 2021-12-01 04:00:00  4.920503e+07   BTC   BTC
# 2021-12-01 05:00:00  3.238116e+07   BTC   BTC
# ...                           ...   ...   ...
# 2021-12-12 23:00:00  1.230245e+05  COMP   ETH
# 2021-12-13 00:00:00  5.911383e+04  COMP   ETH
# 2021-12-13 01:00:00  6.637839e+05  COMP   ETH
# 2021-12-13 02:00:00  3.697480e+05  COMP   ETH
# 2021-12-13 03:00:00  8.747343e+04  COMP   ETH
#
# [1455 rows x 8 columns]

# %%
df.drop(columns='volumeUSD')
# Out:
#                          open      high       low     close       volume  \
# ts
# 2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97   388.482022
# 2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41   599.791578
# 2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83   591.687200
# 2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59   702.560364
# 2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01   859.591535
# ...                       ...       ...       ...       ...          ...
# 2021-12-12 23:00:00    199.71    200.00    197.97    199.27   618.775000
# 2021-12-13 00:00:00    199.27    200.05    198.30    198.62   296.920000
# 2021-12-13 01:00:00    198.52    200.81    195.49    196.24  3363.459000
# 2021-12-13 02:00:00    196.31    196.32    191.80    191.86  1901.019000
# 2021-12-13 03:00:00    191.69    193.47    190.95    192.11   454.858000
#
#                     token chain
# ts
# 2021-12-01 00:00:00   BTC   BTC
# 2021-12-01 01:00:00   BTC   BTC
# 2021-12-01 02:00:00   BTC   BTC
# 2021-12-01 03:00:00   BTC   BTC
# 2021-12-01 04:00:00   BTC   BTC
# ...                   ...   ...
# 2021-12-12 23:00:00  COMP   ETH
# 2021-12-13 00:00:00  COMP   ETH
# 2021-12-13 01:00:00  COMP   ETH
# 2021-12-13 02:00:00  COMP   ETH
# 2021-12-13 03:00:00  COMP   ETH
#
# [1460 rows x 7 columns]

# %%
df.drop(['close', 'open'], axis=1)
# Out:
#                          high       low       volume     volumeUSD token chain
# ts
# 2021-12-01 00:00:00  57451.05  56814.34   388.482022  2.218430e+07   BTC   BTC
# 2021-12-01 01:00:00  57726.45  56705.06   599.791578  3.437153e+07   BTC   BTC
# 2021-12-01 02:00:00  57620.00  56972.97   591.687200  3.387067e+07   BTC   BTC
# 2021-12-01 03:00:00  57396.87  56841.01   702.560364  4.007816e+07   BTC   BTC
# 2021-12-01 04:00:00  57456.82  57026.11   859.591535  4.920503e+07   BTC   BTC
# ...                       ...       ...          ...           ...   ...   ...
# 2021-12-12 23:00:00    200.00    197.97   618.775000  1.230245e+05  COMP   ETH
# 2021-12-13 00:00:00    200.05    198.30   296.920000  5.911383e+04  COMP   ETH
# 2021-12-13 01:00:00    200.81    195.49  3363.459000  6.637839e+05  COMP   ETH
# 2021-12-13 02:00:00    196.32    191.80  1901.019000  3.697480e+05  COMP   ETH
# 2021-12-13 03:00:00    193.47    190.95   454.858000  8.747343e+04  COMP   ETH
#
# [1460 rows x 6 columns]

# %% [markdown]
# ## Common Operations

# %% [markdown]
# Like with pandas Series, a DataFrame is simply a numpy array underneath the hood.

# %%
type(df.values)
# Out:
# numpy.ndarray

# %% [markdown]
# This means that the operations we saw for pandas Series can be applied to DataFrames as well, e.g. we can apply a scalar to every element in the DataFrame

# %%
df.head() * 10
# Out:
#                          open      high       low     close       volume  \
# ts
# 2021-12-01 00:00:00  573214.1  574510.5  568143.4  569879.7  3884.820220
# 2021-12-01 01:00:00  569983.5  577264.5  567050.6  576164.1  5997.915776
# 2021-12-01 02:00:00  576185.5  576200.0  569729.7  570308.3  5916.872000
# 2021-12-01 03:00:00  570297.9  573968.7  568410.1  573075.9  7025.603645
# 2021-12-01 04:00:00  573065.5  574568.2  570261.1  574040.1  8595.915349
#
#                         volumeUSD                           token  \
# ts
# 2021-12-01 00:00:00  2.218430e+08  BTCBTCBTCBTCBTCBTCBTCBTCBTCBTC
# 2021-12-01 01:00:00  3.437153e+08  BTCBTCBTCBTCBTCBTCBTCBTCBTCBTC
# 2021-12-01 02:00:00  3.387067e+08  BTCBTCBTCBTCBTCBTCBTCBTCBTCBTC
# 2021-12-01 03:00:00  4.007816e+08  BTCBTCBTCBTCBTCBTCBTCBTCBTCBTC
# 2021-12-01 04:00:00  4.920503e+08  BTCBTCBTCBTCBTCBTCBTCBTCBTCBTC
#
#                                               chain
# ts
# 2021-12-01 00:00:00  BTCBTCBTCBTCBTCBTCBTCBTCBTCBTC
# 2021-12-01 01:00:00  BTCBTCBTCBTCBTCBTCBTCBTCBTCBTC
# 2021-12-01 02:00:00  BTCBTCBTCBTCBTCBTCBTCBTCBTCBTC
# 2021-12-01 03:00:00  BTCBTCBTCBTCBTCBTCBTCBTCBTCBTC
# 2021-12-01 04:00:00  BTCBTCBTCBTCBTCBTCBTCBTCBTCBTC

# %% [markdown]
# However, the operation needs to be valid for ALL elements if we want to do this - e.g. while `*` is overridden for strings, `/` is not and will fail

# %%
df.head() / 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# ~/opt/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~/opt/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /var/folders/ql/dg9s0kfx7sxg_byk_7xbqbgr0000gn/T/ipykernel_4412/2515165953.py in <module>
# ----> 1 df.head() / 10
#
# ~/opt/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/opt/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/arraylike.py in __truediv__(self, other)
#     114     @unpack_zerodim_and_defer("__truediv__")
#     115     def __truediv__(self, other):
# --> 116         return self._arith_method(other, operator.truediv)
#     117
#     118     @unpack_zerodim_and_defer("__rtruediv__")
#
# ~/opt/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/frame.py in _arith_method(self, other, op)
#    6864         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6865
# -> 6866         new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6867         return self._construct_result(new_data)
#    6868
#
# ~/opt/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/frame.py in _dispatch_frame_op(self, right, func, axis)
#    6891             # i.e. scalar, faster than checking np.ndim(right) == 0
#    6892             with np.errstate(all="ignore"):
# -> 6893                 bm = self._mgr.apply(array_op, right=right)
#    6894             return type(self)(bm)
#    6895
#
# ~/opt/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     323             try:
#     324                 if callable(f):
# --> 325                     applied = b.apply(f, **kwargs)
#     326                 else:
#     327                     applied = getattr(b, f)(**kwargs)
#
# ~/opt/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     379         """
#     380         with np.errstate(all="ignore"):
# --> 381             result = func(self.values, **kwargs)
#     382
#     383         return self._split_op_result(result)
#
# ~/opt/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     222         _bool_arith_check(op, left, right)
#     223
# --> 224         res_values = _na_arithmetic_op(left, right, op)
#     225
#     226     return res_values
#
# ~/opt/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     171             # Don't do this for comparisons, as that will handle complex numbers
#     172             #  incorrectly, see GH#32047
# --> 173             result = _masked_arith_op(left, right, op)
#     174         else:
#     175             raise
#
# ~/opt/anaconda3/envs/mfe-preprogram/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in _masked_arith_op(x, y, op)
#     129
#     130         if mask.any():
# --> 131             result[mask] = op(xrav[mask], y)
#     132
#     133     np.putmask(result, ~mask, np.nan)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# Aggergation functions are by default done by column

# %%
df.mean()
# Out:
# /var/folders/ql/dg9s0kfx7sxg_byk_7xbqbgr0000gn/T/ipykernel_4412/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# open         1.120936e+04
# high         1.127694e+04
# low          1.113114e+04
# close        1.120278e+04
# volume       1.698766e+04
# volumeUSD    1.916371e+07
# dtype: float64

# %% [markdown]
# However we can also make them aggregate by row:

# %%
df.mean(axis=1)
# Out:
# /var/folders/ql/dg9s0kfx7sxg_byk_7xbqbgr0000gn/T/ipykernel_4412/3676274908.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis=1)
# ts
# 2021-12-01 00:00:00    3.735544e+06
# 2021-12-01 01:00:00    5.766863e+06
# 2021-12-01 02:00:00    5.683417e+06
# 2021-12-01 03:00:00    6.717907e+06
# 2021-12-01 04:00:00    8.239181e+06
#                            ...
# 2021-12-12 23:00:00    2.074004e+04
# 2021-12-13 00:00:00    1.003450e+04
# 2021-12-13 01:00:00    1.113231e+05
# 2021-12-13 02:00:00    6.207089e+04
# 2021-12-13 03:00:00    1.478275e+04
# Length: 1460, dtype: float64

# %% [markdown]
# ## Mutating the Dataframe

# %% [markdown]
# Like with other functionality, mutating DataFrames is very similar to mutating Series.  For example, setting one column to a single value is easy:

# %%
df_mutations = df_base.set_index('ts')

# %%
df_mutations.head()
# Out:
#                          open      high       low     close      volume  \
# ts
# 2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97  388.482022
# 2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41  599.791578
# 2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83  591.687200
# 2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59  702.560364
# 2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01  859.591535
#
#                         volumeUSD token chain
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC   BTC
# 2021-12-01 01:00:00  3.437153e+07   BTC   BTC
# 2021-12-01 02:00:00  3.387067e+07   BTC   BTC
# 2021-12-01 03:00:00  4.007816e+07   BTC   BTC
# 2021-12-01 04:00:00  4.920503e+07   BTC   BTC

# %%
df_mutations['chain'] = 'NA'

# %%
df_mutations.head()
# Out:
#                          open      high       low     close      volume  \
# ts
# 2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97  388.482022
# 2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41  599.791578
# 2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83  591.687200
# 2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59  702.560364
# 2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01  859.591535
#
#                         volumeUSD token chain
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC    NA
# 2021-12-01 01:00:00  3.437153e+07   BTC    NA
# 2021-12-01 02:00:00  3.387067e+07   BTC    NA
# 2021-12-01 03:00:00  4.007816e+07   BTC    NA
# 2021-12-01 04:00:00  4.920503e+07   BTC    NA

# %% [markdown]
# We can also create a new column and add data by index:

# %%
updates = pd.Series({pd.to_datetime('2021-12-01 00:00:00'): 1})
updates
# Out:
# 2021-12-01    1
# dtype: int64

# %%
df_mutations['start_of_week'] = updates

# %%
df_mutations.head()
# Out:
#                          open      high       low     close      volume  \
# ts
# 2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97  388.482022
# 2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41  599.791578
# 2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83  591.687200
# 2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59  702.560364
# 2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01  859.591535
#
#                         volumeUSD token chain  start_of_week
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC    NA            1.0
# 2021-12-01 01:00:00  3.437153e+07   BTC    NA            NaN
# 2021-12-01 02:00:00  3.387067e+07   BTC    NA            NaN
# 2021-12-01 03:00:00  4.007816e+07   BTC    NA            NaN
# 2021-12-01 04:00:00  4.920503e+07   BTC    NA            NaN

# %% [markdown]
# We can also use the `.assign(...)` method to update columns, e.g.:

# %%
df_mutations.assign(
    chain=np.where(df_mutations.token.isin(['ETH', 'AAVE', 'COMP']), np.full(df_mutations.shape[0], 'ETH'), df_mutations.token),
    start_of_week=np.NaN
)
# Out:
#                          open      high       low     close       volume  \
# ts
# 2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97   388.482022
# 2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41   599.791578
# 2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83   591.687200
# 2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59   702.560364
# 2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01   859.591535
# ...                       ...       ...       ...       ...          ...
# 2021-12-12 23:00:00    199.71    200.00    197.97    199.27   618.775000
# 2021-12-13 00:00:00    199.27    200.05    198.30    198.62   296.920000
# 2021-12-13 01:00:00    198.52    200.81    195.49    196.24  3363.459000
# 2021-12-13 02:00:00    196.31    196.32    191.80    191.86  1901.019000
# 2021-12-13 03:00:00    191.69    193.47    190.95    192.11   454.858000
#
#                         volumeUSD token chain  start_of_week
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC   BTC            NaN
# 2021-12-01 01:00:00  3.437153e+07   BTC   BTC            NaN
# 2021-12-01 02:00:00  3.387067e+07   BTC   BTC            NaN
# 2021-12-01 03:00:00  4.007816e+07   BTC   BTC            NaN
# 2021-12-01 04:00:00  4.920503e+07   BTC   BTC            NaN
# ...                           ...   ...   ...            ...
# 2021-12-12 23:00:00  1.230245e+05  COMP   ETH            NaN
# 2021-12-13 00:00:00  5.911383e+04  COMP   ETH            NaN
# 2021-12-13 01:00:00  6.637839e+05  COMP   ETH            NaN
# 2021-12-13 02:00:00  3.697480e+05  COMP   ETH            NaN
# 2021-12-13 03:00:00  8.747343e+04  COMP   ETH            NaN
#
# [1460 rows x 9 columns]

# %% [markdown]
# **note**: using the index notation `[*]` will mutate the dataframe in place, however `.assign` will return a new data frame

# %% [markdown]
# We can also rename columns using a `{from:to}` syntax, e.g.:

# %%
df_mutations.rename(
    columns={
        'open':'OpeningPrice',
        'chain':'CryptoChain'
    }
)
# Out:
#                      OpeningPrice      high       low     close       volume  \
# ts
# 2021-12-01 00:00:00      57321.41  57451.05  56814.34  56987.97   388.482022
# 2021-12-01 01:00:00      56998.35  57726.45  56705.06  57616.41   599.791578
# 2021-12-01 02:00:00      57618.55  57620.00  56972.97  57030.83   591.687200
# 2021-12-01 03:00:00      57029.79  57396.87  56841.01  57307.59   702.560364
# 2021-12-01 04:00:00      57306.55  57456.82  57026.11  57404.01   859.591535
# ...                           ...       ...       ...       ...          ...
# 2021-12-12 23:00:00        199.71    200.00    197.97    199.27   618.775000
# 2021-12-13 00:00:00        199.27    200.05    198.30    198.62   296.920000
# 2021-12-13 01:00:00        198.52    200.81    195.49    196.24  3363.459000
# 2021-12-13 02:00:00        196.31    196.32    191.80    191.86  1901.019000
# 2021-12-13 03:00:00        191.69    193.47    190.95    192.11   454.858000
#
#                         volumeUSD token CryptoChain  start_of_week
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC          NA            1.0
# 2021-12-01 01:00:00  3.437153e+07   BTC          NA            NaN
# 2021-12-01 02:00:00  3.387067e+07   BTC          NA            NaN
# 2021-12-01 03:00:00  4.007816e+07   BTC          NA            NaN
# 2021-12-01 04:00:00  4.920503e+07   BTC          NA            NaN
# ...                           ...   ...         ...            ...
# 2021-12-12 23:00:00  1.230245e+05  COMP          NA            NaN
# 2021-12-13 00:00:00  5.911383e+04  COMP          NA            NaN
# 2021-12-13 01:00:00  6.637839e+05  COMP          NA            NaN
# 2021-12-13 02:00:00  3.697480e+05  COMP          NA            NaN
# 2021-12-13 03:00:00  8.747343e+04  COMP          NA            NaN
#
# [1460 rows x 9 columns]

# %% [markdown]
# We can also use functions to rename, e.g.:

# %%
df_mutations.rename(columns=lambda x: x.upper())
# Out:
#                          OPEN      HIGH       LOW     CLOSE       VOLUME  \
# ts
# 2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97   388.482022
# 2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41   599.791578
# 2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83   591.687200
# 2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59   702.560364
# 2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01   859.591535
# ...                       ...       ...       ...       ...          ...
# 2021-12-12 23:00:00    199.71    200.00    197.97    199.27   618.775000
# 2021-12-13 00:00:00    199.27    200.05    198.30    198.62   296.920000
# 2021-12-13 01:00:00    198.52    200.81    195.49    196.24  3363.459000
# 2021-12-13 02:00:00    196.31    196.32    191.80    191.86  1901.019000
# 2021-12-13 03:00:00    191.69    193.47    190.95    192.11   454.858000
#
#                         VOLUMEUSD TOKEN CHAIN  START_OF_WEEK
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC    NA            1.0
# 2021-12-01 01:00:00  3.437153e+07   BTC    NA            NaN
# 2021-12-01 02:00:00  3.387067e+07   BTC    NA            NaN
# 2021-12-01 03:00:00  4.007816e+07   BTC    NA            NaN
# 2021-12-01 04:00:00  4.920503e+07   BTC    NA            NaN
# ...                           ...   ...   ...            ...
# 2021-12-12 23:00:00  1.230245e+05  COMP    NA            NaN
# 2021-12-13 00:00:00  5.911383e+04  COMP    NA            NaN
# 2021-12-13 01:00:00  6.637839e+05  COMP    NA            NaN
# 2021-12-13 02:00:00  3.697480e+05  COMP    NA            NaN
# 2021-12-13 03:00:00  8.747343e+04  COMP    NA            NaN
#
# [1460 rows x 9 columns]

# %% [markdown]
# The above commands will return a new DataFrame.  If we want to rename the input DataFrame, we can use the `inplace` option (which is available on most mutating functions), such as:

# %%
df_mutations.rename(
    columns={
        'open':'OpeningPrice',
        'chain':'CryptoChain'
    },
    inplace=True
)

df_mutations
# Out:
#                      OpeningPrice      high       low     close       volume  \
# ts
# 2021-12-01 00:00:00      57321.41  57451.05  56814.34  56987.97   388.482022
# 2021-12-01 01:00:00      56998.35  57726.45  56705.06  57616.41   599.791578
# 2021-12-01 02:00:00      57618.55  57620.00  56972.97  57030.83   591.687200
# 2021-12-01 03:00:00      57029.79  57396.87  56841.01  57307.59   702.560364
# 2021-12-01 04:00:00      57306.55  57456.82  57026.11  57404.01   859.591535
# ...                           ...       ...       ...       ...          ...
# 2021-12-12 23:00:00        199.71    200.00    197.97    199.27   618.775000
# 2021-12-13 00:00:00        199.27    200.05    198.30    198.62   296.920000
# 2021-12-13 01:00:00        198.52    200.81    195.49    196.24  3363.459000
# 2021-12-13 02:00:00        196.31    196.32    191.80    191.86  1901.019000
# 2021-12-13 03:00:00        191.69    193.47    190.95    192.11   454.858000
#
#                         volumeUSD token CryptoChain  start_of_week
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC          NA            1.0
# 2021-12-01 01:00:00  3.437153e+07   BTC          NA            NaN
# 2021-12-01 02:00:00  3.387067e+07   BTC          NA            NaN
# 2021-12-01 03:00:00  4.007816e+07   BTC          NA            NaN
# 2021-12-01 04:00:00  4.920503e+07   BTC          NA            NaN
# ...                           ...   ...         ...            ...
# 2021-12-12 23:00:00  1.230245e+05  COMP          NA            NaN
# 2021-12-13 00:00:00  5.911383e+04  COMP          NA            NaN
# 2021-12-13 01:00:00  6.637839e+05  COMP          NA            NaN
# 2021-12-13 02:00:00  3.697480e+05  COMP          NA            NaN
# 2021-12-13 03:00:00  8.747343e+04  COMP          NA            NaN
#
# [1460 rows x 9 columns]

# %% [markdown]
# We can also add rows to the DataFrame by using `append`:

# %%
df_mutations.append(
    pd.Series({
        'high': 1,
        'low': 2,
        'token': 'FAKE'
    }, name=pd.to_datetime('2021-11-30 00:00:00'))
)
# Out:
#                      OpeningPrice      high       low     close       volume  \
# ts
# 2021-12-01 00:00:00      57321.41  57451.05  56814.34  56987.97   388.482022
# 2021-12-01 01:00:00      56998.35  57726.45  56705.06  57616.41   599.791578
# 2021-12-01 02:00:00      57618.55  57620.00  56972.97  57030.83   591.687200
# 2021-12-01 03:00:00      57029.79  57396.87  56841.01  57307.59   702.560364
# 2021-12-01 04:00:00      57306.55  57456.82  57026.11  57404.01   859.591535
# ...                           ...       ...       ...       ...          ...
# 2021-12-13 00:00:00        199.27    200.05    198.30    198.62   296.920000
# 2021-12-13 01:00:00        198.52    200.81    195.49    196.24  3363.459000
# 2021-12-13 02:00:00        196.31    196.32    191.80    191.86  1901.019000
# 2021-12-13 03:00:00        191.69    193.47    190.95    192.11   454.858000
# 2021-11-30 00:00:00           NaN      1.00      2.00       NaN          NaN
#
#                         volumeUSD token CryptoChain  start_of_week
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC          NA            1.0
# 2021-12-01 01:00:00  3.437153e+07   BTC          NA            NaN
# 2021-12-01 02:00:00  3.387067e+07   BTC          NA            NaN
# 2021-12-01 03:00:00  4.007816e+07   BTC          NA            NaN
# 2021-12-01 04:00:00  4.920503e+07   BTC          NA            NaN
# ...                           ...   ...         ...            ...
# 2021-12-13 00:00:00  5.911383e+04  COMP          NA            NaN
# 2021-12-13 01:00:00  6.637839e+05  COMP          NA            NaN
# 2021-12-13 02:00:00  3.697480e+05  COMP          NA            NaN
# 2021-12-13 03:00:00  8.747343e+04  COMP          NA            NaN
# 2021-11-30 00:00:00           NaN  FAKE         NaN            NaN
#
# [1461 rows x 9 columns]

# %% [markdown]
# ## Sorting DataFrames

# %% [markdown]
# One thing that we didn't need to really do with Series is sorting.  For DataFrames, we will often need to sort by column(s) or by the index.  We can use `sort_values` and `sort_index` to do this

# %%
df.sort_values('open')
# Out:
#                          open      high       low     close         volume  \
# ts
# 2021-12-11 02:00:00    165.28    171.32    164.68    168.19   80534.167000
# 2021-12-11 01:00:00    166.98    170.41    162.92    167.91    6946.601000
# 2021-12-11 01:00:00    167.63    169.86    161.51    165.32  276907.405000
# 2021-12-11 02:00:00    167.75    171.36    167.46    169.45    1740.741000
# 2021-12-11 04:00:00    168.00    172.00    167.68    170.27   57054.990000
# ...                       ...       ...       ...       ...            ...
# 2021-12-01 15:00:00  57706.57  58783.16  57704.98  58610.19     908.858596
# 2021-12-01 19:00:00  58037.52  58148.15  57423.59  57498.26     851.152400
# 2021-12-01 18:00:00  58485.88  58631.40  58007.24  58037.51     633.239868
# 2021-12-01 16:00:00  58610.19  58900.00  58349.19  58664.40     684.590976
# 2021-12-01 17:00:00  58664.40  59118.84  58445.53  58485.88     728.515015
#
#                         volumeUSD token chain
# ts
# 2021-12-11 02:00:00  1.351489e+07   SOL   SOL
# 2021-12-11 01:00:00  1.159482e+06  AAVE   ETH
# 2021-12-11 01:00:00  4.597063e+07   SOL   SOL
# 2021-12-11 02:00:00  2.957224e+05  AAVE   ETH
# 2021-12-11 04:00:00  9.721131e+06   SOL   SOL
# ...                           ...   ...   ...
# 2021-12-01 15:00:00  5.303393e+07   BTC   BTC
# 2021-12-01 19:00:00  4.917105e+07   BTC   BTC
# 2021-12-01 18:00:00  3.697725e+07   BTC   BTC
# 2021-12-01 16:00:00  4.012464e+07   BTC   BTC
# 2021-12-01 17:00:00  4.285684e+07   BTC   BTC
#
# [1460 rows x 8 columns]

# %%
df.sort_values('open', ascending=False)
# Out:
#                          open      high       low     close         volume  \
# ts
# 2021-12-01 17:00:00  58664.40  59118.84  58445.53  58485.88     728.515015
# 2021-12-01 16:00:00  58610.19  58900.00  58349.19  58664.40     684.590976
# 2021-12-01 18:00:00  58485.88  58631.40  58007.24  58037.51     633.239868
# 2021-12-01 19:00:00  58037.52  58148.15  57423.59  57498.26     851.152400
# 2021-12-01 15:00:00  57706.57  58783.16  57704.98  58610.19     908.858596
# ...                       ...       ...       ...       ...            ...
# 2021-12-11 04:00:00    168.00    172.00    167.68    170.27   57054.990000
# 2021-12-11 02:00:00    167.75    171.36    167.46    169.45    1740.741000
# 2021-12-11 01:00:00    167.63    169.86    161.51    165.32  276907.405000
# 2021-12-11 01:00:00    166.98    170.41    162.92    167.91    6946.601000
# 2021-12-11 02:00:00    165.28    171.32    164.68    168.19   80534.167000
#
#                         volumeUSD token chain
# ts
# 2021-12-01 17:00:00  4.285684e+07   BTC   BTC
# 2021-12-01 16:00:00  4.012464e+07   BTC   BTC
# 2021-12-01 18:00:00  3.697725e+07   BTC   BTC
# 2021-12-01 19:00:00  4.917105e+07   BTC   BTC
# 2021-12-01 15:00:00  5.303393e+07   BTC   BTC
# ...                           ...   ...   ...
# 2021-12-11 04:00:00  9.721131e+06   SOL   SOL
# 2021-12-11 02:00:00  2.957224e+05  AAVE   ETH
# 2021-12-11 01:00:00  4.597063e+07   SOL   SOL
# 2021-12-11 01:00:00  1.159482e+06  AAVE   ETH
# 2021-12-11 02:00:00  1.351489e+07   SOL   SOL
#
# [1460 rows x 8 columns]

# %%
df.sort_values(['volumeUSD', 'open'])
# Out:
#                          open      high       low     close        volume  \
# ts
# 2021-12-02 08:00:00    270.71    272.13    270.58    270.89     67.178000
# 2021-12-12 08:00:00    195.65    195.98    194.83    195.27    134.849000
# 2021-12-01 10:00:00    283.07    284.40    282.27    284.10    123.910000
# 2021-12-12 08:00:00    179.22    179.62    178.58    179.41    211.370000
# 2021-12-02 11:00:00    270.56    271.60    269.00    269.85    151.092000
# ...                       ...       ...       ...       ...           ...
# 2021-12-03 21:00:00  53842.35  54060.00  51640.00  53494.99   3584.238130
# 2021-12-03 17:00:00   4469.68   4469.68   4320.00   4344.51  44978.935447
# 2021-12-03 21:00:00   4229.09   4229.09   4035.00   4212.34  51723.840085
# 2021-12-04 06:00:00   4022.66   4038.80   3575.00   3884.54  97097.417492
# 2021-12-04 06:00:00  50357.06  50608.86  42333.00  47846.62   8420.715164
#
#                         volumeUSD token chain
# ts
# 2021-12-02 08:00:00  1.821233e+04  COMP   ETH
# 2021-12-12 08:00:00  2.635749e+04  COMP   ETH
# 2021-12-01 10:00:00  3.510889e+04  COMP   ETH
# 2021-12-12 08:00:00  3.787862e+04  AAVE   ETH
# 2021-12-02 11:00:00  4.080482e+04  COMP   ETH
# ...                           ...   ...   ...
# 2021-12-03 21:00:00  1.905032e+08   BTC   BTC
# 2021-12-03 17:00:00  1.973315e+08   ETH   ETH
# 2021-12-03 21:00:00  2.147795e+08   ETH   ETH
# 2021-12-04 06:00:00  3.702769e+08   ETH   ETH
# 2021-12-04 06:00:00  3.988035e+08   BTC   BTC
#
# [1460 rows x 8 columns]

# %% [markdown]
# We can also sort by the index

# %%
df.sort_index()
# Out:
#                           open       high        low      close        volume  \
# ts
# 2021-12-01 00:00:00  57321.410  57451.050  56814.340  56987.970    388.482022
# 2021-12-01 00:00:00   4656.620   4672.430   4624.160   4634.950   6013.006735
# 2021-12-01 00:00:00    257.102    260.775    255.345    257.078   2730.299000
# 2021-12-01 00:00:00    210.312    210.590    208.432    208.676  70031.618000
# 2021-12-01 00:00:00    280.590    281.400    278.300    278.700    207.849000
# ...                        ...        ...        ...        ...           ...
# 2021-12-13 03:00:00    173.700    175.250    173.510    174.170    647.711000
# 2021-12-13 03:00:00   3970.920   3999.900   3954.270   3979.890   7376.954839
# 2021-12-13 03:00:00  48625.720  48912.180  48464.660  48756.750    448.845398
# 2021-12-13 03:00:00    168.060    169.380    167.180    167.910  38452.462000
# 2021-12-13 03:00:00    191.690    193.470    190.950    192.110    454.858000
#
#                         volumeUSD token chain
# ts
# 2021-12-01 00:00:00  2.218430e+07   BTC   BTC
# 2021-12-01 00:00:00  2.793321e+07   ETH   ETH
# 2021-12-01 00:00:00  7.039183e+05  AAVE   ETH
# 2021-12-01 00:00:00  1.465851e+07   SOL   SOL
# 2021-12-01 00:00:00  5.822157e+04  COMP   ETH
# ...                           ...   ...   ...
# 2021-12-13 03:00:00  1.129002e+05  AAVE   ETH
# 2021-12-13 03:00:00  2.936103e+07   ETH   ETH
# 2021-12-13 03:00:00  2.186516e+07   BTC   BTC
# 2021-12-13 03:00:00  6.474621e+06   SOL   SOL
# 2021-12-13 03:00:00  8.747343e+04  COMP   ETH
#
# [1460 rows x 8 columns]

# %% [markdown]
# ## Grouping DataFrames

# %% [markdown]
# one _very common_ action we will do during data manipulation is grouping then aggregating.  Pandas DataFrame has the method `groupby`, which allows us to group by any column in our DataFrame.
#
# `groupby` returns a `DataFrameGroupBy` object, which we can apply a function to each group, or directly aggregate

# %%
df.groupby('chain')

# %%
df.groupby('chain').groups
# Out:
# {'BTC': [2021-12-01 00:00:00, 2021-12-01 01:00:00, 2021-12-01 02:00:00, 2021-12-01 03:00:00, 2021-12-01 04:00:00, 2021-12-01 05:00:00, 2021-12-01 06:00:00, 2021-12-01 07:00:00, 2021-12-01 08:00:00, 2021-12-01 09:00:00, 2021-12-01 10:00:00, 2021-12-01 11:00:00, 2021-12-01 12:00:00, 2021-12-01 13:00:00, 2021-12-01 14:00:00, 2021-12-01 15:00:00, 2021-12-01 16:00:00, 2021-12-01 17:00:00, 2021-12-01 18:00:00, 2021-12-01 19:00:00, 2021-12-01 20:00:00, 2021-12-01 21:00:00, 2021-12-01 22:00:00, 2021-12-01 23:00:00, 2021-12-02 00:00:00, 2021-12-02 01:00:00, 2021-12-02 02:00:00, 2021-12-02 03:00:00, 2021-12-02 04:00:00, 2021-12-02 05:00:00, 2021-12-02 06:00:00, 2021-12-02 07:00:00, 2021-12-02 08:00:00, 2021-12-02 09:00:00, 2021-12-02 10:00:00, 2021-12-02 11:00:00, 2021-12-02 12:00:00, 2021-12-02 13:00:00, 2021-12-02 14:00:00, 2021-12-02 15:00:00, 2021-12-02 16:00:00, 2021-12-02 17:00:00, 2021-12-02 18:00:00, 2021-12-02 19:00:00, 2021-12-02 20:00:00, 2021-12-02 21:00:00, 2021-12-02 22:00:00, 2021-12-02 23:00:00, 2021-12-03 00:00:00, 2021-12-03 01:00:00, 2021-12-03 02:00:00, 2021-12-03 03:00:00, 2021-12-03 04:00:00, 2021-12-03 05:00:00, 2021-12-03 06:00:00, 2021-12-03 07:00:00, 2021-12-03 08:00:00, 2021-12-03 09:00:00, 2021-12-03 10:00:00, 2021-12-03 11:00:00, 2021-12-03 12:00:00, 2021-12-03 13:00:00, 2021-12-03 14:00:00, 2021-12-03 15:00:00, 2021-12-03 16:00:00, 2021-12-03 17:00:00, 2021-12-03 18:00:00, 2021-12-03 19:00:00, 2021-12-03 20:00:00, 2021-12-03 21:00:00, 2021-12-03 22:00:00, 2021-12-03 23:00:00, 2021-12-04 00:00:00, 2021-12-04 01:00:00, 2021-12-04 02:00:00, 2021-12-04 03:00:00, 2021-12-04 04:00:00, 2021-12-04 05:00:00, 2021-12-04 06:00:00, 2021-12-04 07:00:00, 2021-12-04 08:00:00, 2021-12-04 09:00:00, 2021-12-04 10:00:00, 2021-12-04 11:00:00, 2021-12-04 12:00:00, 2021-12-04 13:00:00, 2021-12-04 14:00:00, 2021-12-04 15:00:00, 2021-12-04 16:00:00, 2021-12-04 17:00:00, 2021-12-04 18:00:00, 2021-12-04 19:00:00, 2021-12-04 20:00:00, 2021-12-04 21:00:00, 2021-12-04 22:00:00, 2021-12-04 23:00:00, 2021-12-05 00:00:00, 2021-12-05 01:00:00, 2021-12-05 02:00:00, 2021-12-05 03:00:00, ...], 'ETH': [2021-12-01 00:00:00, 2021-12-01 01:00:00, 2021-12-01 02:00:00, 2021-12-01 03:00:00, 2021-12-01 04:00:00, 2021-12-01 05:00:00, 2021-12-01 06:00:00, 2021-12-01 07:00:00, 2021-12-01 08:00:00, 2021-12-01 09:00:00, 2021-12-01 10:00:00, 2021-12-01 11:00:00, 2021-12-01 12:00:00, 2021-12-01 13:00:00, 2021-12-01 14:00:00, 2021-12-01 15:00:00, 2021-12-01 16:00:00, 2021-12-01 17:00:00, 2021-12-01 18:00:00, 2021-12-01 19:00:00, 2021-12-01 20:00:00, 2021-12-01 21:00:00, 2021-12-01 22:00:00, 2021-12-01 23:00:00, 2021-12-02 00:00:00, 2021-12-02 01:00:00, 2021-12-02 02:00:00, 2021-12-02 03:00:00, 2021-12-02 04:00:00, 2021-12-02 05:00:00, 2021-12-02 06:00:00, 2021-12-02 07:00:00, 2021-12-02 08:00:00, 2021-12-02 09:00:00, 2021-12-02 10:00:00, 2021-12-02 11:00:00, 2021-12-02 12:00:00, 2021-12-02 13:00:00, 2021-12-02 14:00:00, 2021-12-02 15:00:00, 2021-12-02 16:00:00, 2021-12-02 17:00:00, 2021-12-02 18:00:00, 2021-12-02 19:00:00, 2021-12-02 20:00:00, 2021-12-02 21:00:00, 2021-12-02 22:00:00, 2021-12-02 23:00:00, 2021-12-03 00:00:00, 2021-12-03 01:00:00, 2021-12-03 02:00:00, 2021-12-03 03:00:00, 2021-12-03 04:00:00, 2021-12-03 05:00:00, 2021-12-03 06:00:00, 2021-12-03 07:00:00, 2021-12-03 08:00:00, 2021-12-03 09:00:00, 2021-12-03 10:00:00, 2021-12-03 11:00:00, 2021-12-03 12:00:00, 2021-12-03 13:00:00, 2021-12-03 14:00:00, 2021-12-03 15:00:00, 2021-12-03 16:00:00, 2021-12-03 17:00:00, 2021-12-03 18:00:00, 2021-12-03 19:00:00, 2021-12-03 20:00:00, 2021-12-03 21:00:00, 2021-12-03 22:00:00, 2021-12-03 23:00:00, 2021-12-04 00:00:00, 2021-12-04 01:00:00, 2021-12-04 02:00:00, 2021-12-04 03:00:00, 2021-12-04 04:00:00, 2021-12-04 05:00:00, 2021-12-04 06:00:00, 2021-12-04 07:00:00, 2021-12-04 08:00:00, 2021-12-04 09:00:00, 2021-12-04 10:00:00, 2021-12-04 11:00:00, 2021-12-04 12:00:00, 2021-12-04 13:00:00, 2021-12-04 14:00:00, 2021-12-04 15:00:00, 2021-12-04 16:00:00, 2021-12- ...

# %%
len(df.groupby('chain'))
# Out:
# 3

# %%
df.groupby('chain').size()
# Out:
# chain
# BTC    292
# ETH    876
# SOL    292
# dtype: int64

# %% [markdown]
# after grouping, we can operate on the whole DataFrame or on any column

# %%
df.groupby('chain')['volumeUSD'].sum().to_frame()
# Out:
#           volumeUSD
# chain
# BTC    1.091870e+10
# ETH    1.300667e+10
# SOL    4.053649e+09

# %% [markdown]
# we can also groupby multiple columns.  The row indices now are a multi-index, however we will not go into this

# %%
df.groupby(['chain', 'token'])['volumeUSD'].sum().to_frame()
# Out:
#                 volumeUSD
# chain token
# BTC   BTC    1.091870e+10
# ETH   AAVE   1.430826e+08
#       COMP   7.253554e+07
#       ETH    1.279105e+10
# SOL   SOL    4.053649e+09

# %% [markdown]
# We can actually aggregate without setting a compound index by adding `as_index=False`

# %%
df.groupby(['chain', 'token'], as_index=False)['volumeUSD'].sum()
# Out:
#   chain token     volumeUSD
# 0   BTC   BTC  1.091870e+10
# 1   ETH  AAVE  1.430826e+08
# 2   ETH  COMP  7.253554e+07
# 3   ETH   ETH  1.279105e+10
# 4   SOL   SOL  4.053649e+09

# %% [markdown]
# We can now operate on the groups.  For example, if we wanted to sum all columns:

# %%
df.groupby('chain').aggregate(np.sum)
# Out:
#                open          high           low         close        volume  \
# chain
# BTC    1.493860e+07  1.502706e+07  1.483654e+07  1.492990e+07  2.153074e+05
# ETH    1.369844e+06  1.379454e+06  1.358360e+06  1.368992e+06  4.093601e+06
# SOL    5.721107e+04  5.781438e+04  5.656171e+04  5.716828e+04  2.049307e+07
#
#           volumeUSD
# chain
# BTC    1.091870e+10
# ETH    1.300667e+10
# SOL    4.053649e+09

# %% [markdown]
# or describe all columns

# %%
df.groupby('chain').describe()
# Out:
#         open                                                                \
#        count          mean          std       min          25%         50%
# chain
# BTC    292.0  51159.604247  3408.256653  46588.66  48684.55250  49612.0350
# ETH    876.0   1563.749171  1915.277243    166.98    195.04875    232.4190
# SOL    292.0    195.928322    20.239565    165.28    180.54250    192.5405
#
#                                high                ...        volume  \
#               75%        max  count          mean  ...           75%
# chain                                              ...
# BTC    53446.8775  58664.400  292.0  51462.540171  ...    919.558897
# ETH     4064.7750   4772.600  876.0   1574.719150  ...   5781.047960
# SOL      209.1150    242.099  292.0    197.994445  ...  84399.865750
#
#                      volumeUSD                                            \
#                  max     count          mean           std           min
# chain
# BTC      8420.715164     292.0  3.739282e+07  3.127329e+07  8.737496e+06
# ETH     97097.417492     876.0  1.484779e+07  2.908290e+07  1.821233e+04
# SOL    534212.095000     292.0  1.388236e+07  9.829576e+06  1.781884e+06
#
#
#                 25%           50%           75%           max
# chain
# BTC    2.017780e+07  3.208078e+07  4.614977e+07  3.988035e+08
# ETH    1.969494e+05  4.621537e+05  2.194393e+07  3.702769e+08
# SOL    7.776958e+06  1.200529e+07  1.680370e+07  9.940887e+07
#
# [3 rows x 48 columns]

# %% [markdown]
# We can also do multiple aggregations

# %%
df.groupby('chain')['open'].agg([np.size, np.mean, np.std, np.min, np.max])
# Out:
#        size          mean          std      amin       amax
# chain
# BTC     292  51159.604247  3408.256653  46588.66  58664.400
# ETH     876   1563.749171  1915.277243    166.98   4772.600
# SOL     292    195.928322    20.239565    165.28    242.099

# %% [markdown]
# we can actually use _any_ arbitrary functions - for example, we can use lambdas

# %%
df.groupby('chain')['open'].agg(
    range=lambda x: x.max() - x.min()
)
# Out:
#            range
# chain
# BTC    12075.740
# ETH     4605.620
# SOL       76.819

# %% [markdown]
# ## Joining Dataframes

# %% [markdown]
# One of the primary things we need to do before starting to clean data is to make sure that we can get all of our data into one place.  This is usually called either a fat talbe or a long table, depending on how we are doing the joining.  We'll look at a few different ways to join pandas DataFrames below.
#
# We will be using `dfs`, which is a list of DataFrames that we created up above

# %% [markdown]
# ### `pd.concat`

# %% [markdown]
# To join the dataframes lengthwise, we can use `pd.concat`.  This will append the dataframes together, and join the rows by using the column names as an index.  If any dataframe doesn't have a column name another one has, it will appear in the full DataFrame but will have NA for the missing DataFrames

# %%
pd.concat(dfs)
# Out:
#                      ts      open      high       low     close       volume  \
# 0   2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97   388.482022
# 1   2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41   599.791578
# 2   2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83   591.687200
# 3   2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59   702.560364
# 4   2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01   859.591535
# ..                  ...       ...       ...       ...       ...          ...
# 287 2021-12-12 23:00:00    199.71    200.00    197.97    199.27   618.775000
# 288 2021-12-13 00:00:00    199.27    200.05    198.30    198.62   296.920000
# 289 2021-12-13 01:00:00    198.52    200.81    195.49    196.24  3363.459000
# 290 2021-12-13 02:00:00    196.31    196.32    191.80    191.86  1901.019000
# 291 2021-12-13 03:00:00    191.69    193.47    190.95    192.11   454.858000
#
#         volumeUSD token chain
# 0    2.218430e+07   BTC   BTC
# 1    3.437153e+07   BTC   BTC
# 2    3.387067e+07   BTC   BTC
# 3    4.007816e+07   BTC   BTC
# 4    4.920503e+07   BTC   BTC
# ..            ...   ...   ...
# 287  1.230245e+05  COMP   ETH
# 288  5.911383e+04  COMP   ETH
# 289  6.637839e+05  COMP   ETH
# 290  3.697480e+05  COMP   ETH
# 291  8.747343e+04  COMP   ETH
#
# [1460 rows x 9 columns]

# %% [markdown]
# if you wanted to make sure you know where the original data is from, we can add keys, which creates a multi index:

# %%
res = pd.concat(dfs, keys=tokens)
res
# Out:
#                           ts      open      high       low     close  \
# BTC  0   2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97
#      1   2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41
#      2   2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83
#      3   2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59
#      4   2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01
# ...                      ...       ...       ...       ...       ...
# COMP 287 2021-12-12 23:00:00    199.71    200.00    197.97    199.27
#      288 2021-12-13 00:00:00    199.27    200.05    198.30    198.62
#      289 2021-12-13 01:00:00    198.52    200.81    195.49    196.24
#      290 2021-12-13 02:00:00    196.31    196.32    191.80    191.86
#      291 2021-12-13 03:00:00    191.69    193.47    190.95    192.11
#
#                volume     volumeUSD token chain
# BTC  0     388.482022  2.218430e+07   BTC   BTC
#      1     599.791578  3.437153e+07   BTC   BTC
#      2     591.687200  3.387067e+07   BTC   BTC
#      3     702.560364  4.007816e+07   BTC   BTC
#      4     859.591535  4.920503e+07   BTC   BTC
# ...               ...           ...   ...   ...
# COMP 287   618.775000  1.230245e+05  COMP   ETH
#      288   296.920000  5.911383e+04  COMP   ETH
#      289  3363.459000  6.637839e+05  COMP   ETH
#      290  1901.019000  3.697480e+05  COMP   ETH
#      291   454.858000  8.747343e+04  COMP   ETH
#
# [1460 rows x 9 columns]

# %% [markdown]
# this allows us to select the data from the source tables, e.g.:

# %%
res.loc['COMP']
# Out:
#                      ts    open    high     low   close    volume  \
# 0   2021-12-01 00:00:00  280.59  281.40  278.30  278.70   207.849
# 1   2021-12-01 01:00:00  278.65  283.80  276.36  283.44   817.668
# 2   2021-12-01 02:00:00  283.20  283.20  280.61  281.29   254.330
# 3   2021-12-01 03:00:00  281.25  283.22  279.90  283.09   393.771
# 4   2021-12-01 04:00:00  283.10  284.16  282.60  283.73   489.120
# ..                  ...     ...     ...     ...     ...       ...
# 287 2021-12-12 23:00:00  199.71  200.00  197.97  199.27   618.775
# 288 2021-12-13 00:00:00  199.27  200.05  198.30  198.62   296.920
# 289 2021-12-13 01:00:00  198.52  200.81  195.49  196.24  3363.459
# 290 2021-12-13 02:00:00  196.31  196.32  191.80  191.86  1901.019
# 291 2021-12-13 03:00:00  191.69  193.47  190.95  192.11   454.858
#
#         volumeUSD token chain
# 0     58221.57184  COMP   ETH
# 1    229274.61550  COMP   ETH
# 2     71609.32568  COMP   ETH
# 3    110890.74168  COMP   ETH
# 4    138532.76788  COMP   ETH
# ..            ...   ...   ...
# 287  123024.49025  COMP   ETH
# 288   59113.82992  COMP   ETH
# 289  663783.90199  COMP   ETH
# 290  369748.01226  COMP   ETH
# 291   87473.43382  COMP   ETH
#
# [292 rows x 9 columns]

# %% [markdown]
# As we saw above, we can also use `.append(*)` on DataFrames as well as Series

# %%
dfs[0].append(dfs[1])
# Out:
#                      ts      open      high       low     close        volume  \
# 0   2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97    388.482022
# 1   2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41    599.791578
# 2   2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83    591.687200
# 3   2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59    702.560364
# 4   2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01    859.591535
# ..                  ...       ...       ...       ...       ...           ...
# 287 2021-12-12 23:00:00   4124.78   4158.00   4116.49   4156.67   3011.092519
# 288 2021-12-13 00:00:00   4156.84   4172.00   4127.40   4132.92   5090.836084
# 289 2021-12-13 01:00:00   4132.91   4146.10   4056.82   4069.44   7688.171067
# 290 2021-12-13 02:00:00   4070.58   4070.58   3961.85   3970.92  18723.615566
# 291 2021-12-13 03:00:00   3970.92   3999.90   3954.27   3979.36   7374.032111
#
#         volumeUSD token chain
# 0    2.218430e+07   BTC   BTC
# 1    3.437153e+07   BTC   BTC
# 2    3.387067e+07   BTC   BTC
# 3    4.007816e+07   BTC   BTC
# 4    4.920503e+07   BTC   BTC
# ..            ...   ...   ...
# 287  1.245128e+07   ETH   ETH
# 288  2.113033e+07   ETH   ETH
# 289  3.153781e+07   ETH   ETH
# 290  7.507152e+07   ETH   ETH
# 291  2.934940e+07   ETH   ETH
#
# [584 rows x 9 columns]

# %% [markdown]
# Lastly, remember the importance of indices.  In the operation above (both `.concat` and `.append`) we joined the DataFrames while keeping the indices of the original tables.  This means that we have repeated indices:

# %%
dfs[0].append(dfs[1]).sort_index()
# Out:
#                      ts      open      high       low     close        volume  \
# 0   2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97    388.482022
# 0   2021-12-01 00:00:00   4656.62   4672.43   4624.16   4634.95   6013.006735
# 1   2021-12-01 01:00:00   4636.43   4736.90   4605.49   4729.10  13819.061610
# 1   2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41    599.791578
# 2   2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83    591.687200
# ..                  ...       ...       ...       ...       ...           ...
# 289 2021-12-13 01:00:00  50089.64  50218.42  49570.70  49652.89    419.303095
# 290 2021-12-13 02:00:00   4070.58   4070.58   3961.85   3970.92  18723.615566
# 290 2021-12-13 02:00:00  49663.75  49664.16  48595.01  48624.41    929.600989
# 291 2021-12-13 03:00:00  48625.72  48912.18  48464.66  48758.38    448.678884
# 291 2021-12-13 03:00:00   3970.92   3999.90   3954.27   3979.36   7374.032111
#
#         volumeUSD token chain
# 0    2.218430e+07   BTC   BTC
# 0    2.793321e+07   ETH   ETH
# 1    6.487693e+07   ETH   ETH
# 1    3.437153e+07   BTC   BTC
# 2    3.387067e+07   BTC   BTC
# ..            ...   ...   ...
# 289  2.091323e+07   BTC   BTC
# 290  7.507152e+07   ETH   ETH
# 290  4.568805e+07   BTC   BTC
# 291  2.185704e+07   BTC   BTC
# 291  2.934940e+07   ETH   ETH
#
# [584 rows x 9 columns]

# %% [markdown]
# This sometimes isn't ideal, esp. if we want to join against these indices later.  Instead, we can create a new index on the joined table using the `ignore_index` parameter, which allows us to have a sequential, non-repeated index:

# %%
dfs[0].append(dfs[1], ignore_index=True).sort_index()
# Out:
#                      ts      open      high       low     close        volume  \
# 0   2021-12-01 00:00:00  57321.41  57451.05  56814.34  56987.97    388.482022
# 1   2021-12-01 01:00:00  56998.35  57726.45  56705.06  57616.41    599.791578
# 2   2021-12-01 02:00:00  57618.55  57620.00  56972.97  57030.83    591.687200
# 3   2021-12-01 03:00:00  57029.79  57396.87  56841.01  57307.59    702.560364
# 4   2021-12-01 04:00:00  57306.55  57456.82  57026.11  57404.01    859.591535
# ..                  ...       ...       ...       ...       ...           ...
# 579 2021-12-12 23:00:00   4124.78   4158.00   4116.49   4156.67   3011.092519
# 580 2021-12-13 00:00:00   4156.84   4172.00   4127.40   4132.92   5090.836084
# 581 2021-12-13 01:00:00   4132.91   4146.10   4056.82   4069.44   7688.171067
# 582 2021-12-13 02:00:00   4070.58   4070.58   3961.85   3970.92  18723.615566
# 583 2021-12-13 03:00:00   3970.92   3999.90   3954.27   3979.36   7374.032111
#
#         volumeUSD token chain
# 0    2.218430e+07   BTC   BTC
# 1    3.437153e+07   BTC   BTC
# 2    3.387067e+07   BTC   BTC
# 3    4.007816e+07   BTC   BTC
# 4    4.920503e+07   BTC   BTC
# ..            ...   ...   ...
# 579  1.245128e+07   ETH   ETH
# 580  2.113033e+07   ETH   ETH
# 581  3.153781e+07   ETH   ETH
# 582  7.507152e+07   ETH   ETH
# 583  2.934940e+07   ETH   ETH
#
# [584 rows x 9 columns]

# %% [markdown]
# ### `pd.DataFrame.join`

# %% [markdown]
# `df.join` is a nice and easy method that allows us to join two dataframes by their index

# %%
dfs[0].set_index('ts')['close'].rename(f'close_{tokens[0]}').to_frame().join(
    dfs[1].set_index('ts')['close'].rename(f'close_{tokens[1]}').to_frame()
)
# Out:
#                      close_BTC  close_ETH
# ts
# 2021-12-01 00:00:00   56987.97    4634.95
# 2021-12-01 01:00:00   57616.41    4729.10
# 2021-12-01 02:00:00   57030.83    4695.78
# 2021-12-01 03:00:00   57307.59    4754.09
# 2021-12-01 04:00:00   57404.01    4764.59
# ...                        ...        ...
# 2021-12-12 23:00:00   50317.33    4156.67
# 2021-12-13 00:00:00   50089.64    4132.92
# 2021-12-13 01:00:00   49652.89    4069.44
# 2021-12-13 02:00:00   48624.41    3970.92
# 2021-12-13 03:00:00   48758.38    3979.36
#
# [292 rows x 2 columns]

# %% [markdown]
# we can get a little more advanced by having a **left** unkeyed DataFrame joining against a **right** keyed DataFrame, e.g.:

# %%
dfs[0][['ts', 'close']].join(
    dfs[1].set_index('ts')['close'].rename(f'close_{tokens[1]}').to_frame(),
    on='ts'
)
# Out:
#                      ts     close  close_ETH
# 0   2021-12-01 00:00:00  56987.97    4634.95
# 1   2021-12-01 01:00:00  57616.41    4729.10
# 2   2021-12-01 02:00:00  57030.83    4695.78
# 3   2021-12-01 03:00:00  57307.59    4754.09
# 4   2021-12-01 04:00:00  57404.01    4764.59
# ..                  ...       ...        ...
# 287 2021-12-12 23:00:00  50317.33    4156.67
# 288 2021-12-13 00:00:00  50089.64    4132.92
# 289 2021-12-13 01:00:00  49652.89    4069.44
# 290 2021-12-13 02:00:00  48624.41    3970.92
# 291 2021-12-13 03:00:00  48758.38    3979.36
#
# [292 rows x 3 columns]

# %% [markdown]
# ### `pd.merge`

# %% [markdown]
# `pd.merge` is Pandas way of doing sql-like joins (e.g. left join, inner join, outer join etc).  There are a few quirks we'll see though.

# %%
pd.merge(
    dfs[0][['ts', 'close']].rename(columns={'close': f'close_{tokens[0]}'}),
    dfs[1][['ts', 'close']].rename(columns={'close': f'close_{tokens[1]}'}),
    on='ts',
    how='inner'
)
# Out:
#                      ts  close_BTC  close_ETH
# 0   2021-12-01 00:00:00   56987.97    4634.95
# 1   2021-12-01 01:00:00   57616.41    4729.10
# 2   2021-12-01 02:00:00   57030.83    4695.78
# 3   2021-12-01 03:00:00   57307.59    4754.09
# 4   2021-12-01 04:00:00   57404.01    4764.59
# ..                  ...        ...        ...
# 287 2021-12-12 23:00:00   50317.33    4156.67
# 288 2021-12-13 00:00:00   50089.64    4132.92
# 289 2021-12-13 01:00:00   49652.89    4069.44
# 290 2021-12-13 02:00:00   48624.41    3970.92
# 291 2021-12-13 03:00:00   48758.38    3979.36
#
# [292 rows x 3 columns]

# %% [markdown]
# we can use other conditions for `how`, e.g. 'left', 'right', 'outer', and 'cross'

# %% [markdown]
# if left and right DataFrames have columns with the same name, pandas will automatically resolve the delta by adding `_x` and `_y` suffixes to the conflicted columns

# %%
pd.merge(
    dfs[0][['ts', 'close']],
    dfs[1][['ts', 'close']],
    on='ts',
    how='inner'
)
# Out:
#                      ts   close_x  close_y
# 0   2021-12-01 00:00:00  56987.97  4634.95
# 1   2021-12-01 01:00:00  57616.41  4729.10
# 2   2021-12-01 02:00:00  57030.83  4695.78
# 3   2021-12-01 03:00:00  57307.59  4754.09
# 4   2021-12-01 04:00:00  57404.01  4764.59
# ..                  ...       ...      ...
# 287 2021-12-12 23:00:00  50317.33  4156.67
# 288 2021-12-13 00:00:00  50089.64  4132.92
# 289 2021-12-13 01:00:00  49652.89  4069.44
# 290 2021-12-13 02:00:00  48624.41  3970.92
# 291 2021-12-13 03:00:00  48758.38  3979.36
#
# [292 rows x 3 columns]

# %% [markdown]
# however, we can also define our own suffixes, e.g.

# %%
pd.merge(
    dfs[0][['ts', 'close']],
    dfs[1][['ts', 'close']],
    on='ts',
    how='inner',
    suffixes=[f'_{tokens[0]}', f'_{tokens[1]}']
)
